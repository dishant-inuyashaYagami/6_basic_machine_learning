# %% [markdown]
# ## ==========  MULTI CLASSIFICATION: CLEVR DATA SET  ==============

# %% [markdown]
# ### Reading Input Dataset: Image Pixels & Class Labels

# %%
import csv
import os

# %%
import numpy as np 
import copy
import sys
import pdb
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt 
from sklearn.preprocessing import OneHotEncoder

def get_data(x_path, y_path, doNormalize):
    ''' Returns: x: np array of [NUM_OF_SAMPLES x n]  y: np array of [NUM_OF_SAMPLES]
    '''
    x = np.load(x_path)
    y = np.load(y_path)
    

    y = y.astype('float')
    x = x.astype('float')

    #normalize x:
    if doNormalize:
        x = 2*(0.5 - x/255)
    return x, y

x_train, y_train = get_data("/Users/dishantgoyal/Desktop/ml/0_neural_network_classification/clevr/x_train.npy", "/Users/dishantgoyal/Desktop/ml/0_neural_network_classification/clevr/y_train.npy", 1)
x_test,   y_test = get_data("/Users/dishantgoyal/Desktop/ml/0_neural_network_classification/clevr/x_test.npy", "/Users/dishantgoyal/Desktop/ml/0_neural_network_classification/clevr/y_test.txt", 1)
print ("training data det:          ", x_train)
print ("\ntraining class labels:    ", y_train)
print ("\ntesting data det:         ", x_test)
print ("\ntesting class labels:     ", y_test)
print ("\nsize of single sample:      ", len(x_train[0]))
print ("number of training samples: ", len(x_train))
print ("number of testing  samples: ", x_test.shape)
# Out:
# training data det:           [[ 0.21568627  0.21568627  0.21568627 ... -0.19215686 -0.15294118
#   -1.        ]
#  [ 0.21568627  0.21568627  0.22352941 ... -0.19215686 -0.15294118
#   -1.        ]
#  [ 0.21568627  0.21568627  0.22352941 ... -0.2        -0.15294118
#   -1.        ]
#  ...
#  [ 0.21568627  0.21568627  0.21568627 ... -0.19215686 -0.14509804
#   -1.        ]
#  [ 0.21568627  0.21568627  0.21568627 ... -0.19215686 -0.14509804
#   -1.        ]
#  [ 0.21568627  0.21568627  0.21568627 ... -0.19215686 -0.15294118
#   -1.        ]]
#
# training class labels:     [1. 3. 4. ... 4. 3. 2.]
#
# testing data det:          [[ 0.20784314  0.21568627  0.21568627 ... -0.19215686 -0.15294118
#   -1.        ]
#  [ 0.21568627  0.21568627  0.22352941 ... -0.19215686 -0.15294118
#   -1.        ]
#  [ 0.20784314  0.21568627  0.21568627 ... -0.19215686 -0.15294118
#   -1.        ]
#  ...
#  [ 0.21568627  0.21568627  0.21568627 ... -0.19215686 -0.14509804
#   -1.        ]
#  [ 0.21568627  0.21568627  0.21568627 ... -0.19215686 -0.14509804
#   -1.        ]
#  [ 0.21568627  0.21568627  0.21568627 ... -0.19215686 -0.15294118
#   -1.        ]]
#
# testing class labels:      [1. 4. 2. 2. 2. 1. 1. 2. 1. 5. 3. 5. 3. 1. 2. 1. 1. 1. 2. 4. 4. 3. 1. 3.
#  4. 5. 2. 3. 1. 1. 5. 1. 5. 4. 2. 1. 2. 5. 1. 1. 3. 2. 2. 3. 5. 4. 3. 4.
#  4. 1. 5. 3. 2. 2. 3. 4. 2. 2. 5. 3. 1. 1. 5. 2. 4. 4. 3. 3. 1. 3. 5. 2.
#  1. 3. 3. 1. 4. 2. 4. 5. 3. 4. 1. 3. 1. 2. 5. 4. 3. 4. 5. 5. 4. 5. 4. 1.
#  3. 3. 1. 3. 2. 1. 1. 5. 3. 5. 1. 4. 2. 4. 5. 1. 4. 1. 5. 2. 3. 5. 2. 5.
#  2. 5. 3. 2. 3. 3. 3. 3. 5. 3. 1. 2. 4. 3. 2. 4. 5. 4. 3. 5. 4. 4. 3. 4.
#  4. 2. 2. 1. 1. 1. 4. 1. 1. 5. 4. 1. 2. 4. 3. 4. 1. 3. 4. 1. 3. 5. 1. 2.
#  1. 3. 1. 1. 3. 4. 2. 2. 5. 5. 2. 1. 4. 3. 5. 5. 4. 3. 2. 5. 5. 3. 1. 2.
#  4. 1. 3. 4. 3. 2. 4. 1. 4. 4. 5. 1. 2. 3. 3. 2. 5. 4. 4. 3. 3. 4. 3. 5.
#  5. 1. 3. 3. 4. 5. 3. 3. 1. 5. 4. 1. 3. 2. 5. 2. 3. 5. 2. 4. 2. 3. 3. 3.
#  3. 5. 5. 5. 5. 5. 1. 2. 5. 2. 5. 1. 1. 4. 5. 1. 1. 3. 3. 4. 4. 5. 1. 2.
#  3. 1. 5. 1. 1. 2. 5. 5. 2. 3. 4. 4. 3. 1. 4. 3. 4. 1. 2. 3. 1. 3. 3. 3.
#  4. 5. 2. 1. 1. 3. 3. 5. 1. 3. 2. 3. 1. 5. 3. 5. 1. 5. 1. 3. 2. 5. 4. 2.
#  4. 1. 2. 3. 5. 4. 2. 4. 2. 4. 3. 2. 3. 5. 3. 5. 2. 4. 5. 2. 1. 3. 5. 2.
#  4. 5. 3. 3. 3. 5. 2. 2. 3. 4. 1. 5. 5. 2. 4. 1. 3. 5. 2. 3. 4. 1. 3. 3.
#  1. 1. 1. 2. 4. 2. 4. 2. 3. 5. 5. 3. 1. 5. 5. 1. 3. 4. 1. 4. 1. 1. 4. 4.
#  1. 2. 5. 3. 4. 3. 1. 3. 2. 3. 2. 3. 2. 4. 4. 3. 2. 1. 2. 4. 5. 4. 2. 3.
#  3. 1. 5. 5. 4. 4. 3. 1. 2. 1. 4. 1. 2. 5. 2. 4. 1. 1. 4. 3. 5. 2. 4. 5.
#  1. 2. 3. 3. 5. 4. 1. 4. 3. 1. 5. 5. 4. 5. 5. 4. 5. 4. 2. 1. 2. 5. 2. 4.
#  3. 1. 2. 1. 3. 2. 2. 4. 4. 2. 1. 3. 5. 3. 2. 5. 2. 3. 1. 5. 5. 3. 2. 5.
#  3. 3. 5. 5. 3. 3. 4. 2. 5. 2. 2. 5. 1. 1. 3. 1. 2. 1. 4. 5. 2. 5. 3. 4.
#  1. 3. 5. 4. 1. 4. 3. 1. 2. 4. 1. 3. 1. 1. 4. 1. 2. 2. 1. 2. 4. 3. 5. 1.
#  1. 5. 1. 4. 1. 5. 5. 5. 3. 5. 1. 4. 2. 1. 5. 1. 2. 4. 5. 1. 2. 3. 5. 4.
#  5. 3. 4. 5. 1. 5. 1. 4. 3. 1. 1. 2. 3. 4. 3. 4. 5. 4. 3. 3. 5. 2. 3. 1.
#  5. 4. 2. 2. 3. 3. 2. 3. 2. 1. 5. 2. 3. 1. 3. 5. 3. 1. 2. 4. 5. 5. 2. 2.
#  1. 1. 4. 3. 5. 5. 5. 4. 1. 1. 3. 3. 5. 1. 4. 2. 3. 5. 1. 2. 3. 1. 3. 1.
#  3. 5. 4. 4. 4. 1. 1. 2. 5. 2. 3. 3. 4. 5. 4. 4. 3. 5. 1. 3. 3. 2. 2. 5.
#  3. 2. 4. 2. 1. 4. 3. 3. 1. 1. 1. 3. 2. 3. 4. 2. 1. 2. 1. 4. 2. 4. 4. 2.
#  5. 2. 3. 5. 1. 5. 4. 1. 5. 5. 1. 3. 5. 4. 3. 5. 3. 2. 5. 4. 4. 2. 3. 4.
#  4. 5. 1. 3. 3. 5. 2. 3. 4. 5. 4. 1. 2. 5. 2. 5. 2. 3. 3. 4. 4. 1. 4. 4.
#  5. 2. 5. 5. 2. 1. 1. 1. 5. 2. 4. 3. 3. 3. 1. 2. 2. 1. 4. 3. 2. 4. 2. 2.
#  5. 1. 5. 1. 2. 2. 5. 4. 1. 3. 5. 4. 2. 4. 4. 2. 1. 4. 2. 4. 1. 1. 2. 3.
#  2. 3. 2. 4. 2. 2. 1. 5. 2. 3. 2. 3. 3. 1. 4. 1. 3. 2. 4. 1. 5. 3. 2. 3.
#  4. 5. 2. 5. 3. 3. 5. 5. 4. 1. 5. 2. 4. 2. 4. 1. 1. 5. 4. 3. 5. 1. 4. 2.
#  1. 1. 4. 2. 3. 3. 5. 5. 4. 5. 4. 3. 5. 5. 1. 4. 3. 5. 4. 5. 5. 1. 4. 4.
#  4. 1. 2. 1. 1. 2. 1. 5. 4. 4. 5. 4. 3. 1. 3. 5. 2. 1. 4. 4. 2. 5. 4. 1.
#  1. 1. 3. 3. 5. 1. 4. 3. 1. 5. 1. 2. 1. 5. 1. 1. 5. 4. 5. 4. 4. 4. 2. 1.
#  5. 3. 2. 1. 5. 1. 3. 2. 1. 2. 5. 5. 4. 3. 5. 1. 3. 4. 5. 4. 2. 2. 3. 5.
#  3. 3. 1. 2. 4. 4. 4. 4. 4. 2. 1. 4. 1. 4. 1. 5. 1. 1. 3. 3. 3. 2. 2. 2.
#  1. 1. 3. 4. 1. 3. 5. 4. 5. 1. 2. 2. 3. 4. 1. 3. 4. 3. 1. 2. 2. 1. 4. 5.
#  3. 1. 1. 3. 5. 1. 3. 2. 1. 1. 2. 3. 2. 1. 3. 3. 3. 3. 3. 5. 3. 4. 4. 3.
#  1. 2. 3. 2. 3. 3. 5. 4. 3. 3. 3. 5. 5. 5. 1. 3.]
#
# size of single sample:       1024
# number of training samples:  10000
# number of testing  samples:  (10000, 1024)

# %% [markdown]
# ### Example Image

# %%
x_train_rgb, y_train = get_data("/Users/dishantgoyal/Desktop/ml/0_neural_network_classification/clevr/x_train.npy", "/Users/dishantgoyal/Desktop/ml/0_neural_network_classification/clevr/y_train.npy", 0)
x_test_rgb,  y_test = get_data("/Users/dishantgoyal/Desktop/ml/0_neural_network_classification/clevr/x_test.npy", "/Users/dishantgoyal/Desktop/ml/0_neural_network_classification/clevr/y_test.txt", 0)

from matplotlib import pyplot as plt
index = 4
img = np.reshape(np.uint64(x_train_rgb[index]), (16, 16, 4))
plt.imshow(img)
plt.axis('off')  # Turn off the axis
plt.show
print ("number of boxes in the image: ", y_train[index])
# Out:
# number of boxes in the image:  3.0

# %% [markdown]
# ### Distribution of Class Labels

# %%
unique_labels  = np.unique(y_train)
label_count    = np.bincount(np.int64(y_train))

print ("[train] unique labels:      ", unique_labels)
print ("[train] count distribution: ", label_count)

unique_labels  = np.unique(y_test)
label_count    = np.bincount(np.int64(y_test))

print ("[test]  unique labels:      ", unique_labels)
print ("[test]  count distribution: ", label_count)
# Out:
# [train] unique labels:       [1. 2. 3. 4. 5.]
# [train] count distribution:  [   0 1971 1978 1952 2008 2091]
# [test]  unique labels:       [1. 2. 3. 4. 5.]
# [test]  count distribution:  [  0 214 183 219 191 193]

# %% [markdown]
# ### Neural Network Design Parameters

# %%
learning_rate         = 0.01
enable_adaptive_learn = 1
batch_size            = 32
initial_num_features  = len(x_train[0])
hidden_layer_list     = [512, 256, 128, 64, 32]
num_classes           = 5
hidden_layer_list.append(num_classes)
num_layers            = len(hidden_layer_list)
train_size            = len(x_train)
test_size             = len(x_test)

print ("batch size:        ", batch_size)
print ("num features:      ", initial_num_features)
print ("hiden layers size: ", hidden_layer_list)
print ("number of layers:  ", num_layers)
print ("number of classes: ", num_classes)
print ("size of training:  ", train_size)
print ("size of test:      ", test_size)
# Out:
# batch size:         32
# num features:       1024
# hiden layers size:  [512, 256, 128, 64, 32, 5]
# number of layers:   6
# number of classes:  5
# size of training:   10000
# size of test:       10000

# %% [markdown]
# ### Initialize Perceptron Parameters

# %%
row_length            = initial_num_features
list_parameter_matrix = []                                      # at index i, stores the parameter matrix for corresponding hidden layer

for layer in range(0, len(hidden_layer_list)):        # traversing the hidden layer from left to right
    num_rows    = hidden_layer_list[layer]
    para_matrix = np.zeros((num_rows, row_length))    # all parameters initialized to 0.5 initially
    para_matrix = np.random.uniform(-1,1,(num_rows, row_length))
    #para_matrix.fill(0.2) 
    list_parameter_matrix.append(para_matrix)
    row_length  = num_rows                            # for the next hidden layer

print ("number of parameter matricies: ", len(list_parameter_matrix))
# Out:
# number of parameter matricies:  6

# %% [markdown]
# ### Computing Output Probabilities Every Perceptron

# %%
import math
e = math.e

def softmax_best_pr (output_values, pr, class_label, example_index, isTrain):            # for the final probability
    #mx_value       = pow(e,output_values.max())
    class_label[0] = output_values.argmax() + 1
    train_inp      = pow(e, output_values)                       # input to the last single softmax-perceptron
    sum_values     = train_inp.sum()
    if isTrain:
        pr[0]          = train_inp[int(y_train[example_index])-1]/sum_values

# %%
def compute_error(train_acc, error, distribution): 
    train_acc[0]    = 0
    error[0]        = 0

    for index in range(start_range[0], end_range[0]):
        output       = [None]*num_layers
        train_inp    = x_train[index]           # row of attributes
        for layer in range(0, num_layers):
            output[layer]  = np.matmul(list_parameter_matrix[layer],  train_inp.transpose())
            for pindex in range(0, np.shape(output[layer])[0]):
                if (output[layer][pindex] > 20):                   # to avoid numerical warnings/errors
                    output[layer][pindex]  = 1
                elif (output[layer][pindex] < -20):
                    output[layer][pindex]  = 0
                else:
                    output[layer][pindex]  = 1/(1+pow(e, -1*output[layer][pindex]))                                       # using sigmoid g(z)
            train_inp      = copy.deepcopy(output[layer])                                         # fetch as input to next layer
        final_pr         = [0]
        predicted_label  = [0]
        softmax_best_pr (output[num_layers-1], final_pr, predicted_label, index, 1)    # isTrain = 1
        if predicted_label[0] == y_train[index]:
            train_acc[0] += 1
            distribution[y_train[index] -1] += 1
        
        if final_pr[0] != 0: 
            error[0] += -1*math.log(final_pr[0])               # log likelyhood
        else:
            error[0] += 999999
        output_list.append(output)

# %%
def compute_full_accuracy (full_acc, distribution, isTrain):     # computes the full accuracy of the training and test datas sets
    full_acc[0]    = 0
    for index in range(0, len(x_train)):
        output       = [None]*num_layers
        
        if isTrain:
            train_inp    = x_train[index]           # row of attributes
        else:
            train_inp    = x_test[index]            # row of attributes
            
        for layer in range(0, num_layers):
            output[layer]  = np.matmul(list_parameter_matrix[layer],  train_inp.transpose())
            for pindex in range(0, np.shape(output[layer])[0]):
                if (output[layer][pindex] > 20):                   # to avoid numerical warnings/errors
                    output[layer][pindex]  = 1
                elif (output[layer][pindex] < -20):
                    output[layer][pindex]  = 0
                else:
                    output[layer][pindex]  = 1/(1+pow(e, -1*output[layer][pindex]))                                       # using sigmoid g(z)
            train_inp      = copy.deepcopy(output[layer])                                         # fetch as input to next layer
        final_pr         = [0]
        predicted_label  = [0]
        softmax_best_pr (output[num_layers-1], final_pr, predicted_label, index, isTrain)
        
        if isTrain:
            if predicted_label[0] == y_train[index]:
                full_acc[0] += 1
                distribution[y_train[index] -1] += 1
        else:
            if predicted_label[0] == y_test[index]:
                full_acc[0] += 1
                distribution[y_test[index] -1] += 1

# %% [markdown]
# ### Computing Gradient: Simple Backpropagation
#
# ##### each hidden layer:   0-1   sigmoid
# ##### last layer:                 multi sigmoid (softmax)
# ##### loss function:          cross-entropy (basically log likelyhood)

# %%
num_para_hidLay_list  = [initial_num_features] + hidden_layer_list
print ("parameter size for each perceptron of hidden layer: ", num_para_hidLay_list)

def update_parameters():
    old_para_matrix       = copy.deepcopy(list_parameter_matrix)      ## store the old parameters in a separate varaible
    grad_para_x           = copy.deepcopy(list_parameter_matrix)      ## grad x     ### dummy values  ## will be computed further
    grad_para_t           = copy.deepcopy(list_parameter_matrix)      ## grad theta ### dummy values  ## will be computed further

    for example_index in range(start_range[0], end_range[0]):
        for layer in range(num_layers-1, -1, -1):                # traverse the layers in reverse order
            if layer+1 == num_layers:
                train_inp      = pow(e, output_list[example_index][layer])                       # input to the last single softmax-perceptron
                sum_values     = train_inp.sum()
                sum_para_ary   = train_inp/sum_values
                sum_para_ary[int(y_train[example_index])-1] -= 1
            else:
                sum_para_ary = grad_para_x[layer+1].sum(axis=0)
            
            grad_gz        = 1 - output_list[example_index][layer]
            grad_gz        = np.multiply(grad_gz, output_list[example_index][layer])
            perceptron_ary = np.multiply(grad_gz, sum_para_ary)
            if layer == 0:                                               # [None,:] makes shape (,5)  --->  (1,5)
                grad_para_t[layer]        =  np.matmul(perceptron_ary[None,:].transpose(), x_train[example_index][None,:])
            else:
                grad_para_t[layer]        =  np.matmul(perceptron_ary[None,:].transpose(), output_list[example_index][layer-1][None,:]) 
            list_parameter_matrix[layer] -=  grad_para_t[layer]*learning_rate
            
            grad_para_x[layer]            =  old_para_matrix[layer]*perceptron_ary[None,:].transpose()
# Out:
# parameter size for each perceptron of hidden layer:  [1024, 512, 256, 128, 64, 32, 5]

# %% [markdown]
# ### Gradient Descent

# %%
flag = 0
direction      = 1
num_iter       = 0
error          = [1]
start_range    = [0]
end_range      = [0]
train_acc      = [0]
full_acc       = [0]
max_acc        = 0
distribution   = {0:0,1:0,2:0,3:0,4:0}
num_epochs     = 1
seed_learning_rate = learning_rate

while (error[0] > 0.00001) and num_iter < 100000:
    if start_range[0] == 0:
        output_list  = []                  # output[index] stores the list of outputs for training example_index <index> 
    end_range[0] = start_range[0] + batch_size 
    
    distribution = {0:0,1:0,2:0,3:0,4:0}
    compute_error(train_acc, error, distribution)        # compute the log likelyhood error/cost fn of sum of all examples/data-points
    
    if num_iter%100 == 0:
        print ("\nnum iter      : ", num_iter)
        print ("train accuracy: ", train_acc[0])
        print ("dist          : ", distribution)
        print ("error value   : ", error[0])
        print ("range:          ", start_range[0], end_range[0])

    update_parameters()                # update the parameters of each perceptron using gradient descent
    num_iter +=1;

    start_range[0] = start_range[0] + batch_size
    if (start_range[0] >= 10000-33):
        start_range[0] = 0
        num_epochs += 1
        if enable_adaptive_learn:
            learning_rate = seed_learning_rate/math.sqrt(num_epochs)
            print ("============== new learning rate: ", learning_rate)
        distribution = {0:0,1:0,2:0,3:0,4:0}
        compute_full_accuracy(full_acc, distribution, 1)
        print ("full accuracy : ", full_acc[0])
        print ("dist          : ", distribution)
        if (max_acc < full_acc[0]):
            max_acc = full_acc[0]
        print ("max train accuracy : ", max_acc)
# Out:
# num iter      :  0
# train accuracy:  6
# dist          :  {0: 0, 1: 6, 2: 0, 3: 0, 4: 0}
# error value   :  55.00105845050423
# range:           0 32
#
# num iter      :  100
# train accuracy:  11
# dist          :  {0: 6, 1: 1, 2: 0, 3: 4, 4: 0}
# error value   :  49.73878299553129
# range:           3200 3232
#
# num iter      :  200
# train accuracy:  14
# dist          :  {0: 4, 1: 3, 2: 0, 3: 7, 4: 0}
# error value   :  46.047674681278885
# range:           6400 6432
#
# num iter      :  300
# train accuracy:  16
# dist          :  {0: 7, 1: 3, 2: 1, 3: 0, 4: 5}
# error value   :  42.44315089488192
# range:           9600 9632
# ============== new learning rate:  0.0070710678118654745
# full accuracy :  5475
# dist          :  {0: 1899, 1: 936, 2: 182, 3: 797, 4: 1661}
# max train accuracy :  5475
#
# num iter      :  400
# train accuracy:  22
# dist          :  {0: 7, 1: 7, 2: 2, 3: 2, 4: 4}
# error value   :  40.516797016790264
# range:           2816 2848
#
# num iter      :  500
# train accuracy:  16
# dist          :  {0: 5, 1: 1, 2: 1, 3: 8, 4: 1}
# error value   :  42.349339021420775
# range:           6016 6048
#
# num iter      :  600
# train accuracy:  16
# dist          :  {0: 6, 1: 3, 2: 1, 3: 3, 4: 3}
# error value   :  41.94895460518217
# range:           9216 9248
# ============== new learning rate:  0.005773502691896258
# full accuracy :  6021
# dist          :  {0: 1872, 1: 1220, 2: 534, 3: 916, 4: 1479}
# max train accuracy :  6021
#
# num iter      :  700
# train accuracy:  23
# dist          :  {0: 5, 1: 2, 2: 6, 3: 7, 4: 3}
# error value   :  39.14071948952739
# range:           2432 2464
#
# num iter      :  800
# train accuracy:  22
# dist          :  {0: 4, 1: 7, 2: 2, 3: 6, 4: 3}
# error value   :  40.38653948806648
# range:           5632 5664
#
# num iter      :  900
# train accuracy:  18
# dist          :  {0: 2, 1: 7, 2: 3, 3: 5, 4: 1}
# error value   :  41.44092489825625
# range:           8832 8864
# ============== new learning rate:  0.005
# full accuracy :  6014
# dist          :  {0: 1931, 1: 1113, 2: 711, 3: 1099, 4: 1160}
# max train accuracy :  6021
#
# num iter      :  1000
# train accuracy:  23
# dist          :  {0: 11, 1: 4, 2: 3, 3: 3, 4: 2}
# error value   :  38.0483326277213
# range:           2048 2080
#
# num iter      :  1100
# train accuracy:  21
# dist          :  {0: 6, 1: 9, 2: 0, 3: 5, 4: 1}
# error value   :  37.93756006001982
# range:           5248 5280
#
# num iter      :  1200
# train accuracy:  18
# dist          :  {0: 9, 1: 0, 2: 3, 3: 6, 4: 0}
# error value   :  40.36348784227129
# range:           8448 8480
# ============== new learning rate:  0.004472135954999579
# full accuracy :  5726
# dist          :  {0: 1934, 1: 1152, 2: 796, 3: 1450, 4: 394}
# max train accuracy :  6021
#
# num iter      :  1300
# train accuracy:  21
# dist          :  {0: 9, 1: 3, 2: 1, 3: 6, 4: 2}
# error value   :  39.483687083942286
# range:           1664 1696
#
# num iter      :  1400
# train accuracy:  20
# dist          :  {0: 6, 1: 9, 2: 2, 3: 3, 4: 0}
# error value   :  38.51205687698946
# range:           4864 4896
#
# num iter      :  1500
# train accuracy:  19
# dist          :  {0: 3, 1: 2, 2: 2, 3: 12, 4: 0}
# error value   :  39.840686370601766
# range:           8064 8096
# ============== new learning rate:  0.004082482904638631
# full accuracy :  5611
# dist          :  {0: 1925, 1: 1187, 2: 846, 3: 1594, 4: 59}
# max train accuracy :  6021
#
# num iter      :  1600
# train accuracy:  19
# dist          :  {0: 7, 1: 4, 2: 3, 3: 4, 4: 1}
# error value   :  37.41126656162512
# range:           1280 1312
#
# num iter      :  1700
# train accuracy:  22
# dist          :  {0: 13, 1: 2, 2: 5, 3: 2, 4: 0}
# error value   :  37.22280485973066
# range:           4480 4512
#
# num iter      :  1800
# train accuracy:  14
# dist          :  {0: 6, 1: 4, 2: 2, 3: 2, 4: 0}
# error value   :  39.34972154025658
# range:           7680 7712
# ============== new learning rate:  0.003779644730092272
# full accuracy :  5698
# dist          :  {0: 1917, 1: 1227, 2: 894, 3: 1651, 4: 9}
# max train accuracy :  6021
#
# num iter      :  1900
# train accuracy:  17
# dist          :  {0: 7, 1: 4, 2: 3, 3: 3, 4: 0}
# error value   :  37.78416466516121
# range:           896 928
#
# num iter      :  2000
# train accuracy:  19
# dist          :  {0: 7, 1: 1, 2: 5, 3: 6, 4: 0}
# error value   :  40.14115086896753
# range:           4096 4128
#
# num iter      :  2100
# train accuracy:  14
# dist          :  {0: 6, 1: 6, 2: 2, 3: 0, 4: 0}
# error value   :  36.66202515632778
# range:           7296 7328
# ============== new learning rate:  0.0035355339059327372
# full accuracy :  5781
# dist          :  {0: 1909, 1: 1267, 2: 920, 3: 1682, 4: 3}
# max train accuracy :  6021
#
# num iter      :  2200
# train accuracy:  17
# dist          :  {0: 10, 1: 4, 2: 1, 3: 2, 4: 0}
# error value   :  38.68593375781198
# range:           512 544
#
# num iter      :  2300
# train accuracy:  17
# dist          :  {0: 8, 1: 1, 2: 3, 3: 5, 4: 0}
# error value   :  38.17756723939113
# range:           3712 3744
#
# num iter      :  2400
# train accuracy:  16
# dist          :  {0: 5, 1: 4, 2: 3, 3: 4, 4: 0}
# error value   :  38.11249700727798
# range:           6912 6944
# ============== new learning rate:  0.0033333333333333335
# full accuracy :  5825
# dist          :  {0: 1909, 1: 1286, 2: 935, 3: 1695, 4: 0}
# max train accuracy :  6021
#
# num iter      :  2500
# train accuracy:  20
# dist          :  {0: 5, 1: 6, 2: 3, 3: 6, 4: 0}
# error value   :  36.98694874107686
# range:           128 160
#
# num iter      :  2600
# train accuracy:  22
# dist          :  {0: 8, 1: 3, 2: 5, 3: 6, 4: 0}
# error value   :  37.736988439918996
# range:           3328 3360
#
# num iter      :  2700
# train accuracy:  23
# dist          :  {0: 5, 1: 7, 2: 4, 3: 7, 4: 0}
# error value   :  36.935153960239965
# range:           6528 6560
#
# num iter      :  2800
# train accuracy:  18
# dist          :  {0: 6, 1: 7, 2: 3, 3: 2, 4: 0}
# error value   :  37.32523639997088
# range:           9728 9760
# ============== new learning rate:  0.0031622776601683794
# full accuracy :  5871
# dist          :  {0: 1909, 1: 1309, 2: 956, 3: 1697, 4: 0}
# max train accuracy :  6021
#
# num iter      :  2900
# train accuracy:  12
# dist          :  {0: 4, 1: 4, 2: 2, 3: 2, 4: 0}
# error value   :  39.86181510694673
# range:           2944 2976
#
# num iter      :  3000
# train accuracy:  19
# dist          :  {0: 5, 1: 1, 2: 5, 3: 8, 4: 0}
# error value   :  39.0582896456988
# range:           6144 6176
#
# num iter      :  3100
# train accuracy:  16
# dist          :  {0: 3, 1: 4, 2: 3, 3: 6, 4: 0}
# error value   :  37.992189958438416
# range:           9344 9376
# ============== new learning rate:  0.0030151134457776364
# full accuracy :  5904
# dist          :  {0: 1908, 1: 1323, 2: 965, 3: 1708, 4: 0}
# max train accuracy :  6021
#
# num iter      :  3200
# train accuracy:  17
# dist          :  {0: 5, 1: 6, 2: 2, 3: 4, 4: 0}
# error value   :  38.248383575196655
# range:           2560 2592
#
# num iter      :  3300
# train accuracy:  21
# dist          :  {0: 8, 1: 2, 2: 3, 3: 8, 4: 0}
# error value   :  37.47326003929564
# range:           5760 5792
#
# num iter      :  3400
# train accuracy:  21
# dist          :  {0: 5, 1: 10, 2: 2, 3: 4, 4: 0}
# error value   :  37.76851237168781
# range:           8960 8992
# ============== new learning rate:  0.002886751345948129
# full accuracy :  5937
# dist          :  {0: 1906, 1: 1340, 2: 978, 3: 1713, 4: 0}
# max train accuracy :  6021
#
# num iter      :  3500
# train accuracy:  22
# dist          :  {0: 3, 1: 4, 2: 5, 3: 10, 4: 0}
# error value   :  37.60441769084108
# range:           2176 2208
#
# num iter      :  3600
# train accuracy:  16
# dist          :  {0: 6, 1: 3, 2: 3, 3: 4, 4: 0}
# error value   :  38.61181006757401
# range:           5376 5408
#
# num iter      :  3700
# train accuracy:  18
# dist          :  {0: 10, 1: 0, 2: 2, 3: 6, 4: 0}
# error value   :  37.82324758224017
# range:           8576 8608
# ============== new learning rate:  0.002773500981126146
# full accuracy :  5966
# dist          :  {0: 1907, 1: 1355, 2: 987, 3: 1717, 4: 0}
# max train accuracy :  6021
#
# num iter      :  3800
# train accuracy:  16
# dist          :  {0: 6, 1: 4, 2: 3, 3: 3, 4: 0}
# error value   :  39.50876660800618
# range:           1792 1824
#
# num iter      :  3900
# train accuracy:  18
# dist          :  {0: 5, 1: 3, 2: 4, 3: 6, 4: 0}
# error value   :  39.11877577738371
# range:           4992 5024
#
# num iter      :  4000
# train accuracy:  19
# dist          :  {0: 5, 1: 9, 2: 2, 3: 3, 4: 0}
# error value   :  36.096576539482584
# range:           8192 8224
# ============== new learning rate:  0.002672612419124244
# full accuracy :  5982
# dist          :  {0: 1909, 1: 1361, 2: 1001, 3: 1711, 4: 0}
# max train accuracy :  6021
#
# num iter      :  4100
# train accuracy:  18
# dist          :  {0: 5, 1: 3, 2: 2, 3: 8, 4: 0}
# error value   :  38.806767426477435
# range:           1408 1440
#
# num iter      :  4200
# train accuracy:  20
# dist          :  {0: 10, 1: 6, 2: 2, 3: 2, 4: 0}
# error value   :  37.83051042999099
# range:           4608 4640
#
# num iter      :  4300
# train accuracy:  23
# dist          :  {0: 9, 1: 5, 2: 2, 3: 7, 4: 0}
# error value   :  35.72734477716055
# range:           7808 7840
# ============== new learning rate:  0.0025819888974716113
# full accuracy :  6006
# dist          :  {0: 1911, 1: 1378, 2: 1010, 3: 1707, 4: 0}
# max train accuracy :  6021
#
# num iter      :  4400
# train accuracy:  18
# dist          :  {0: 5, 1: 5, 2: 2, 3: 6, 4: 0}
# error value   :  37.4027206037583
# range:           1024 1056
#
# num iter      :  4500
# train accuracy:  18
# dist          :  {0: 3, 1: 7, 2: 4, 3: 4, 4: 0}
# error value   :  36.52391629280145
# range:           4224 4256
#
# num iter      :  4600
# train accuracy:  17
# dist          :  {0: 3, 1: 5, 2: 2, 3: 7, 4: 0}
# error value   :  37.89652060035219
# range:           7424 7456
# ============== new learning rate:  0.0025
# full accuracy :  6025
# dist          :  {0: 1911, 1: 1400, 2: 1015, 3: 1699, 4: 0}
# max train accuracy :  6025
#
# num iter      :  4700
# train accuracy:  20
# dist          :  {0: 9, 1: 6, 2: 2, 3: 3, 4: 0}
# error value   :  35.70798913821851
# range:           640 672
#
# num iter      :  4800
# train accuracy:  22
# dist          :  {0: 7, 1: 2, 2: 5, 3: 8, 4: 0}
# error value   :  37.56365196758581
# range:           3840 3872
#
# num iter      :  4900
# train accuracy:  19
# dist          :  {0: 6, 1: 5, 2: 4, 3: 4, 4: 0}
# error value   :  36.54128505682868
# range:           7040 7072
# ============== new learning rate:  0.00242535625036333
# full accuracy :  6052
# dist          :  {0: 1913, 1: 1423, 2: 1026, 3: 1690, 4: 0}
# max train accuracy :  6052
#
# num iter      :  5000
# train accuracy:  21
# dist          :  {0: 3, 1: 10, 2: 3, 3: 5, 4: 0}
# error value   :  37.367194027437996
# range:           256 288
#
# num iter      :  5100
# train accuracy:  19
# dist          :  {0: 8, 1: 3, 2: 3, 3: 5, 4: 0}
# error value   :  37.212905740926445
# range:           3456 3488
#
# num iter      :  5200
# train accuracy:  22
# dist          :  {0: 5, 1: 4, 2: 5, 3: 8, 4: 0}
# error value   :  36.055142880115525
# range:           6656 6688
#
# num iter      :  5300
# train accuracy:  21
# dist          :  {0: 2, 1: 7, 2: 4, 3: 8, 4: 0}
# error value   :  37.58661372843784
# range:           9856 9888
# ============== new learning rate:  0.0023570226039551587
# full accuracy :  6095
# dist          :  {0: 1918, 1: 1445, 2: 1049, 3: 1683, 4: 0}
# max train accuracy :  6095
#
# num iter      :  5400
# train accuracy:  21
# dist          :  {0: 4, 1: 4, 2: 3, 3: 10, 4: 0}
# error value   :  38.29726254258292
# range:           3072 3104
#
# num iter      :  5500
# train accuracy:  26
# dist          :  {0: 4, 1: 11, 2: 5, 3: 6, 4: 0}
# error value   :  35.56483237349202
# range:           6272 6304
#
# num iter      :  5600
# train accuracy:  23
# dist          :  {0: 12, 1: 5, 2: 3, 3: 3, 4: 0}
# error value   :  35.02544309475897
# range:           9472 9504
# ============== new learning rate:  0.0022941573387056176
# full accuracy :  6126
# dist          :  {0: 1920, 1: 1466, 2: 1065, 3: 1675, 4: 0}
# max train accuracy :  6126
#
# num iter      :  5700
# train accuracy:  19
# dist          :  {0: 4, 1: 6, 2: 5, 3: 4, 4: 0}
# error value   :  35.85175613668852
# range:           2688 2720
#
# num iter      :  5800
# train accuracy:  24
# dist          :  {0: 6, 1: 6, 2: 1, 3: 11, 4: 0}
# error value   :  37.76058733412621
# range:           5888 5920
#
# num iter      :  5900
# train accuracy:  21
# dist          :  {0: 6, 1: 2, 2: 7, 3: 6, 4: 0}
# error value   :  36.94902229407822
# range:           9088 9120
# ============== new learning rate:  0.0022360679774997894
# full accuracy :  6153
# dist          :  {0: 1921, 1: 1492, 2: 1073, 3: 1667, 4: 0}
# max train accuracy :  6153
#
# num iter      :  6000
# train accuracy:  22
# dist          :  {0: 10, 1: 1, 2: 4, 3: 7, 4: 0}
# error value   :  36.91065739316261
# range:           2304 2336
#
# num iter      :  6100
# train accuracy:  16
# dist          :  {0: 4, 1: 4, 2: 4, 3: 4, 4: 0}
# error value   :  38.368425013407744
# range:           5504 5536
#
# num iter      :  6200
# train accuracy:  18
# dist          :  {0: 4, 1: 6, 2: 4, 3: 4, 4: 0}
# error value   :  39.24538907531877
# range:           8704 8736
# ============== new learning rate:  0.002182178902359924
# full accuracy :  6174
# dist          :  {0: 1923, 1: 1504, 2: 1089, 3: 1658, 4: 0}
# max train accuracy :  6174
#
# num iter      :  6300
# train accuracy:  23
# dist          :  {0: 4, 1: 4, 2: 5, 3: 10, 4: 0}
# error value   :  37.17505358759002
# range:           1920 1952
#
# num iter      :  6400
# train accuracy:  15
# dist          :  {0: 8, 1: 2, 2: 2, 3: 3, 4: 0}
# error value   :  36.246883426664894
# range:           5120 5152
#
# num iter      :  6500
# train accuracy:  18
# dist          :  {0: 4, 1: 5, 2: 5, 3: 4, 4: 0}
# error value   :  36.45999880652713
# range:           8320 8352
# ============== new learning rate:  0.0021320071635561044
# full accuracy :  6200
# dist          :  {0: 1928, 1: 1519, 2: 1100, 3: 1653, 4: 0}
# max train accuracy :  6200
#
# num iter      :  6600
# train accuracy:  13
# dist          :  {0: 2, 1: 5, 2: 2, 3: 4, 4: 0}
# error value   :  38.361139396804354
# range:           1536 1568
#
# num iter      :  6700
# train accuracy:  18
# dist          :  {0: 5, 1: 3, 2: 5, 3: 5, 4: 0}
# error value   :  36.189669954052206
# range:           4736 4768
#
# num iter      :  6800
# train accuracy:  20
# dist          :  {0: 5, 1: 6, 2: 2, 3: 7, 4: 0}
# error value   :  36.11433931002449
# range:           7936 7968
# ============== new learning rate:  0.002085144140570748
# full accuracy :  6209
# dist          :  {0: 1928, 1: 1528, 2: 1108, 3: 1645, 4: 0}
# max train accuracy :  6209
#
# num iter      :  6900
# train accuracy:  22
# dist          :  {0: 6, 1: 7, 2: 4, 3: 5, 4: 0}
# error value   :  35.76908510959333
# range:           1152 1184
#
# num iter      :  7000
# train accuracy:  15
# dist          :  {0: 6, 1: 4, 2: 5, 3: 0, 4: 0}
# error value   :  36.570493644974036
# range:           4352 4384
#
# num iter      :  7100
# train accuracy:  16
# dist          :  {0: 3, 1: 4, 2: 3, 3: 6, 4: 0}
# error value   :  37.04380843784328
# range:           7552 7584
# ============== new learning rate:  0.0020412414523193153
# full accuracy :  6218
# dist          :  {0: 1929, 1: 1539, 2: 1115, 3: 1635, 4: 0}
# max train accuracy :  6218
#
# num iter      :  7200
# train accuracy:  16
# dist          :  {0: 5, 1: 3, 2: 4, 3: 4, 4: 0}
# error value   :  40.059259888484334
# range:           768 800
#
# num iter      :  7300
# train accuracy:  21
# dist          :  {0: 5, 1: 8, 2: 5, 3: 3, 4: 0}
# error value   :  36.075631464765806
# range:           3968 4000
#
# num iter      :  7400
# train accuracy:  22
# dist          :  {0: 7, 1: 6, 2: 4, 3: 5, 4: 0}
# error value   :  36.1455868779377
# range:           7168 7200
# ============== new learning rate:  0.002
# full accuracy :  6230
# dist          :  {0: 1930, 1: 1548, 2: 1122, 3: 1630, 4: 0}
# max train accuracy :  6230
#
# num iter      :  7500
# train accuracy:  24
# dist          :  {0: 3, 1: 8, 2: 7, 3: 6, 4: 0}
# error value   :  34.91088187235972
# range:           384 416
#
# num iter      :  7600
# train accuracy:  21
# dist          :  {0: 3, 1: 6, 2: 2, 3: 10, 4: 0}
# error value   :  36.669378461748195
# range:           3584 3616
#
# num iter      :  7700
# train accuracy:  18
# dist          :  {0: 5, 1: 3, 2: 4, 3: 6, 4: 0}
# error value   :  37.3805780112968
# range:           6784 6816
# ============== new learning rate:  0.0019611613513818406
# full accuracy :  6244
# dist          :  {0: 1931, 1: 1560, 2: 1129, 3: 1624, 4: 0}
# max train accuracy :  6244
#
# num iter      :  7800
# train accuracy:  16
# dist          :  {0: 1, 1: 4, 2: 8, 3: 3, 4: 0}
# error value   :  37.058257079212964
# range:           0 32
#
# num iter      :  7900
# train accuracy:  20
# dist          :  {0: 6, 1: 4, 2: 6, 3: 4, 4: 0}
# error value   :  36.263562133721905
# range:           3200 3232
#
# num iter      :  8000
# train accuracy:  22
# dist          :  {0: 6, 1: 4, 2: 6, 3: 6, 4: 0}
# error value   :  37.384968888480294
# range:           6400 6432
#
# num iter      :  8100
# train accuracy:  23
# dist          :  {0: 10, 1: 6, 2: 3, 3: 4, 4: 0}
# error value   :  35.76679361967711
# range:           9600 9632
# ============== new learning rate:  0.0019245008972987524
# full accuracy :  6264
# dist          :  {0: 1931, 1: 1570, 2: 1144, 3: 1619, 4: 0}
# max train accuracy :  6264
#
# num iter      :  8200
# train accuracy:  20
# dist          :  {0: 8, 1: 7, 2: 2, 3: 3, 4: 0}
# error value   :  34.865150141621974
# range:           2816 2848
#
# num iter      :  8300
# train accuracy:  19
# dist          :  {0: 6, 1: 3, 2: 1, 3: 9, 4: 0}
# error value   :  38.81406338795502
# range:           6016 6048
#
# num iter      :  8400
# train accuracy:  17
# dist          :  {0: 6, 1: 3, 2: 3, 3: 5, 4: 0}
# error value   :  38.16944491100905
# range:           9216 9248
# ============== new learning rate:  0.001889822365046136
# full accuracy :  6286
# dist          :  {0: 1931, 1: 1584, 2: 1154, 3: 1617, 4: 0}
# max train accuracy :  6286
#
# num iter      :  8500
# train accuracy:  21
# dist          :  {0: 5, 1: 2, 2: 6, 3: 8, 4: 0}
# error value   :  35.87523167497241
# range:           2432 2464
#
# num iter      :  8600
# train accuracy:  20
# dist          :  {0: 5, 1: 7, 2: 2, 3: 6, 4: 0}
# error value   :  35.4625811765383
# range:           5632 5664
#
# num iter      :  8700
# train accuracy:  16
# dist          :  {0: 2, 1: 7, 2: 2, 3: 5, 4: 0}
# error value   :  39.252224649717974
# range:           8832 8864
# ============== new learning rate:  0.0018569533817705188
# full accuracy :  6305
# dist          :  {0: 1933, 1: 1596, 2: 1165, 3: 1611, 4: 0}
# max train accuracy :  6305
#
# num iter      :  8800
# train accuracy:  24
# dist          :  {0: 12, 1: 4, 2: 4, 3: 4, 4: 0}
# error value   :  33.996622750908706
# range:           2048 2080
#
# num iter      :  8900
# train accuracy:  19
# dist          :  {0: 5, 1: 9, 2: 0, 3: 5, 4: 0}
# error value   :  34.801241252192426
# range:           5248 5280
#
# num iter      :  9000
# train accuracy:  21
# dist          :  {0: 9, 1: 1, 2: 6, 3: 5, 4: 0}
# error value   :  35.8486424356368
# range:           8448 8480
# ============== new learning rate:  0.0018257418583505537
# full accuracy :  6326
# dist          :  {0: 1937, 1: 1606, 2: 1175, 3: 1608, 4: 0}
# max train accuracy :  6326
#
# num iter      :  9100
# train accuracy:  22
# dist          :  {0: 9, 1: 5, 2: 2, 3: 6, 4: 0}
# error value   :  36.92291440774871
# range:           1664 1696
#
# num iter      :  9200
# train accuracy:  24
# dist          :  {0: 7, 1: 10, 2: 4, 3: 3, 4: 0}
# error value   :  34.303215230550066
# range:           4864 4896
#
# num iter      :  9300
# train accuracy:  20
# dist          :  {0: 3, 1: 3, 2: 2, 3: 12, 4: 0}
# error value   :  37.45812844894139
# range:           8064 8096
# ============== new learning rate:  0.0017960530202677492
# full accuracy :  6338
# dist          :  {0: 1940, 1: 1616, 2: 1179, 3: 1603, 4: 0}
# max train accuracy :  6338
#
# num iter      :  9400
# train accuracy:  18
# dist          :  {0: 7, 1: 3, 2: 4, 3: 4, 4: 0}
# error value   :  35.792408307463354
# range:           1280 1312
#
# num iter      :  9500
# train accuracy:  26
# dist          :  {0: 14, 1: 1, 2: 8, 3: 3, 4: 0}
# error value   :  33.513146752840186
# range:           4480 4512
#
# num iter      :  9600
# train accuracy:  17
# dist          :  {0: 6, 1: 4, 2: 3, 3: 4, 4: 0}
# error value   :  36.69412684492071
# range:           7680 7712
# ============== new learning rate:  0.0017677669529663686
# full accuracy :  6357
# dist          :  {0: 1940, 1: 1622, 2: 1193, 3: 1602, 4: 0}
# max train accuracy :  6357
#
# num iter      :  9700
# train accuracy:  18
# dist          :  {0: 8, 1: 4, 2: 2, 3: 4, 4: 0}
# error value   :  36.35741456893258
# range:           896 928
#
# num iter      :  9800
# train accuracy:  18
# dist          :  {0: 7, 1: 2, 2: 3, 3: 6, 4: 0}
# error value   :  38.91140861014397
# range:           4096 4128
#
# num iter      :  9900
# train accuracy:  18
# dist          :  {0: 7, 1: 7, 2: 3, 3: 1, 4: 0}
# error value   :  34.92336270964287
# range:           7296 7328
# ============== new learning rate:  0.0017407765595569785
# full accuracy :  6373
# dist          :  {0: 1941, 1: 1633, 2: 1200, 3: 1599, 4: 0}
# max train accuracy :  6373
#
# num iter      :  10000
# train accuracy:  19
# dist          :  {0: 10, 1: 4, 2: 4, 3: 1, 4: 0}
# error value   :  36.66047581291996
# range:           512 544
#
# num iter      :  10100
# train accuracy:  19
# dist          :  {0: 8, 1: 2, 2: 3, 3: 6, 4: 0}
# error value   :  37.40461028044831
# range:           3712 3744
#
# num iter      :  10200
# train accuracy:  20
# dist          :  {0: 7, 1: 6, 2: 3, 3: 4, 4: 0}
# error value   :  36.290359464430175
# range:           6912 6944
# ============== new learning rate:  0.0017149858514250882
# full accuracy :  6376
# dist          :  {0: 1942, 1: 1637, 2: 1201, 3: 1596, 4: 0}
# max train accuracy :  6376
#
# num iter      :  10300
# train accuracy:  22
# dist          :  {0: 5, 1: 8, 2: 3, 3: 6, 4: 0}
# error value   :  35.13072137735519
# range:           128 160
#
# num iter      :  10400
# train accuracy:  26
# dist          :  {0: 9, 1: 5, 2: 6, 3: 6, 4: 0}
# error value   :  35.2579953663272
# range:           3328 3360
#
# num iter      :  10500
# train accuracy:  25
# dist          :  {0: 5, 1: 9, 2: 5, 3: 6, 4: 0}
# error value   :  35.421605129621
# range:           6528 6560
#
# num iter      :  10600
# train accuracy:  23
# dist          :  {0: 6, 1: 11, 2: 4, 3: 2, 4: 0}
# error value   :  34.796501463164454
# range:           9728 9760
# ============== new learning rate:  0.0016903085094570332
# full accuracy :  6381
# dist          :  {0: 1942, 1: 1639, 2: 1207, 3: 1593, 4: 0}
# max train accuracy :  6381
#
# num iter      :  10700
# train accuracy:  13
# dist          :  {0: 4, 1: 4, 2: 3, 3: 2, 4: 0}
# error value   :  38.05992823787368
# range:           2944 2976
#
# num iter      :  10800
# train accuracy:  19
# dist          :  {0: 6, 1: 1, 2: 5, 3: 7, 4: 0}
# error value   :  37.59546411531437
# range:           6144 6176
#
# num iter      :  10900
# train accuracy:  17
# dist          :  {0: 3, 1: 5, 2: 3, 3: 6, 4: 0}
# error value   :  35.9533050907427
# range:           9344 9376
# ============== new learning rate:  0.0016666666666666668
# full accuracy :  6395
# dist          :  {0: 1943, 1: 1646, 2: 1215, 3: 1591, 4: 0}
# max train accuracy :  6395
#
# num iter      :  11000
# train accuracy:  20
# dist          :  {0: 5, 1: 7, 2: 3, 3: 5, 4: 0}
# error value   :  36.43164992390174
# range:           2560 2592
#
# num iter      :  11100
# train accuracy:  21
# dist          :  {0: 8, 1: 4, 2: 3, 3: 6, 4: 0}
# error value   :  35.449490832070815
# range:           5760 5792
#
# num iter      :  11200
# train accuracy:  21
# dist          :  {0: 5, 1: 10, 2: 2, 3: 4, 4: 0}
# error value   :  35.55842851824108
# range:           8960 8992
# ============== new learning rate:  0.001643989873053573
# full accuracy :  6404
# dist          :  {0: 1944, 1: 1651, 2: 1221, 3: 1588, 4: 0}
# max train accuracy :  6404
#
# num iter      :  11300
# train accuracy:  23
# dist          :  {0: 3, 1: 4, 2: 6, 3: 10, 4: 0}
# error value   :  35.984321452638824
# range:           2176 2208
#
# num iter      :  11400
# train accuracy:  19
# dist          :  {0: 7, 1: 4, 2: 4, 3: 4, 4: 0}
# error value   :  36.83396411656772
# range:           5376 5408
#
# num iter      :  11500
# train accuracy:  20
# dist          :  {0: 10, 1: 3, 2: 2, 3: 5, 4: 0}
# error value   :  35.29189920494608
# range:           8576 8608
# ============== new learning rate:  0.0016222142113076256
# full accuracy :  6419
# dist          :  {0: 1945, 1: 1656, 2: 1224, 3: 1594, 4: 0}
# max train accuracy :  6419
#
# num iter      :  11600
# train accuracy:  18
# dist          :  {0: 7, 1: 4, 2: 5, 3: 2, 4: 0}
# error value   :  37.71418339798658
# range:           1792 1824
#
# num iter      :  11700
# train accuracy:  19
# dist          :  {0: 5, 1: 4, 2: 4, 3: 6, 4: 0}
# error value   :  36.09616352579456
# range:           4992 5024
#
# num iter      :  11800
# train accuracy:  21
# dist          :  {0: 5, 1: 10, 2: 3, 3: 3, 4: 0}
# error value   :  34.737045545806176
# range:           8192 8224
# ============== new learning rate:  0.0016012815380508714
# full accuracy :  6428
# dist          :  {0: 1945, 1: 1659, 2: 1230, 3: 1594, 4: 0}
# max train accuracy :  6428
#
# num iter      :  11900
# train accuracy:  17
# dist          :  {0: 5, 1: 3, 2: 2, 3: 7, 4: 0}
# error value   :  38.33245200045706
# range:           1408 1440
#
# num iter      :  12000
# train accuracy:  22
# dist          :  {0: 11, 1: 6, 2: 3, 3: 2, 4: 0}
# error value   :  35.877328821573734
# range:           4608 4640
#
# num iter      :  12100
# train accuracy:  25
# dist          :  {0: 10, 1: 5, 2: 2, 3: 8, 4: 0}
# error value   :  34.280960686962764
# range:           7808 7840
# ============== new learning rate:  0.0015811388300841897
# full accuracy :  6434
# dist          :  {0: 1946, 1: 1659, 2: 1234, 3: 1595, 4: 0}
# max train accuracy :  6434
#
# num iter      :  12200
# train accuracy:  20
# dist          :  {0: 5, 1: 6, 2: 3, 3: 6, 4: 0}
# error value   :  37.25143867023806
# range:           1024 1056
#
# num iter      :  12300
# train accuracy:  19
# dist          :  {0: 3, 1: 9, 2: 3, 3: 4, 4: 0}
# error value   :  34.74929473579889
# range:           4224 4256
#
# num iter      :  12400
# train accuracy:  20
# dist          :  {0: 3, 1: 6, 2: 4, 3: 7, 4: 0}
# error value   :  36.13155407758431
# range:           7424 7456
# ============== new learning rate:  0.0015617376188860608
# full accuracy :  6445
# dist          :  {0: 1945, 1: 1665, 2: 1240, 3: 1595, 4: 0}
# max train accuracy :  6445
#
# num iter      :  12500
# train accuracy:  23
# dist          :  {0: 9, 1: 9, 2: 2, 3: 3, 4: 0}
# error value   :  34.502865667792314
# range:           640 672
#
# num iter      :  12600
# train accuracy:  22
# dist          :  {0: 7, 1: 2, 2: 5, 3: 8, 4: 0}
# error value   :  37.132273345281405
# range:           3840 3872
#
# num iter      :  12700
# train accuracy:  20
# dist          :  {0: 6, 1: 6, 2: 4, 3: 4, 4: 0}
# error value   :  34.928238150546974
# range:           7040 7072
# ============== new learning rate:  0.0015430334996209192
# full accuracy :  6467
# dist          :  {0: 1946, 1: 1667, 2: 1254, 3: 1600, 4: 0}
# max train accuracy :  6467
#
# num iter      :  12800
# train accuracy:  23
# dist          :  {0: 4, 1: 11, 2: 3, 3: 5, 4: 0}
# error value   :  36.343950830733725
# range:           256 288
#
# num iter      :  12900
# train accuracy:  20
# dist          :  {0: 9, 1: 3, 2: 2, 3: 6, 4: 0}
# error value   :  36.49370593710305
# range:           3456 3488
#
# num iter      :  13000
# train accuracy:  22
# dist          :  {0: 4, 1: 5, 2: 4, 3: 9, 4: 0}
# error value   :  34.821950445344385
# range:           6656 6688
#
# num iter      :  13100
# train accuracy:  22
# dist          :  {0: 2, 1: 8, 2: 5, 3: 7, 4: 0}
# error value   :  36.475963269255395
# range:           9856 9888
# ============== new learning rate:  0.0015249857033260467
# full accuracy :  6476
# dist          :  {0: 1946, 1: 1675, 2: 1254, 3: 1601, 4: 0}
# max train accuracy :  6476
#
# num iter      :  13200
# train accuracy:  22
# dist          :  {0: 4, 1: 4, 2: 4, 3: 10, 4: 0}
# error value   :  37.38117691850427
# range:           3072 3104
#
# num iter      :  13300
# train accuracy:  23
# dist          :  {0: 4, 1: 11, 2: 3, 3: 5, 4: 0}
# error value   :  34.55330741950369
# range:           6272 6304
#
# num iter      :  13400
# train accuracy:  23
# dist          :  {0: 12, 1: 5, 2: 3, 3: 3, 4: 0}
# error value   :  34.88888095110498
# range:           9472 9504
# ============== new learning rate:  0.0015075567228888182
# full accuracy :  6485
# dist          :  {0: 1947, 1: 1679, 2: 1258, 3: 1601, 4: 0}
# max train accuracy :  6485
#
# num iter      :  13500
# train accuracy:  21
# dist          :  {0: 4, 1: 7, 2: 6, 3: 4, 4: 0}
# error value   :  34.60454950827784
# range:           2688 2720
#
# num iter      :  13600
# train accuracy:  24
# dist          :  {0: 6, 1: 6, 2: 1, 3: 11, 4: 0}
# error value   :  37.12286267343787
# range:           5888 5920
#
# num iter      :  13700
# train accuracy:  26
# dist          :  {0: 6, 1: 3, 2: 10, 3: 7, 4: 0}
# error value   :  35.26270239337557
# range:           9088 9120
# ============== new learning rate:  0.0014907119849998597
# full accuracy :  6487
# dist          :  {0: 1947, 1: 1680, 2: 1258, 3: 1602, 4: 0}
# max train accuracy :  6487
#
# num iter      :  13800
# train accuracy:  24
# dist          :  {0: 10, 1: 2, 2: 5, 3: 7, 4: 0}
# error value   :  35.63046573102665
# range:           2304 2336
#
# num iter      :  13900
# train accuracy:  17
# dist          :  {0: 5, 1: 4, 2: 4, 3: 4, 4: 0}
# error value   :  37.30211510611653
# range:           5504 5536
#
# num iter      :  14000
# train accuracy:  21
# dist          :  {0: 4, 1: 9, 2: 5, 3: 3, 4: 0}
# error value   :  37.12448576230136
# range:           8704 8736
# ============== new learning rate:  0.0014744195615489714
# full accuracy :  6490
# dist          :  {0: 1947, 1: 1681, 2: 1261, 3: 1601, 4: 0}
# max train accuracy :  6490
#
# num iter      :  14100
# train accuracy:  20
# dist          :  {0: 4, 1: 4, 2: 5, 3: 7, 4: 0}
# error value   :  35.67728275769283
# range:           1920 1952
#
# num iter      :  14200
# train accuracy:  14
# dist          :  {0: 8, 1: 2, 2: 1, 3: 3, 4: 0}
# error value   :  35.34787656079262
# range:           5120 5152
#
# num iter      :  14300
# train accuracy:  20
# dist          :  {0: 4, 1: 5, 2: 7, 3: 4, 4: 0}
# error value   :  34.92750745162455
# range:           8320 8352
# ============== new learning rate:  0.0014586499149789457
# full accuracy :  6502
# dist          :  {0: 1949, 1: 1680, 2: 1269, 3: 1604, 4: 0}
# max train accuracy :  6502
#
# num iter      :  14400
# train accuracy:  14
# dist          :  {0: 2, 1: 6, 2: 2, 3: 4, 4: 0}
# error value   :  37.940716247420085
# range:           1536 1568
#
# num iter      :  14500
# train accuracy:  19
# dist          :  {0: 6, 1: 3, 2: 5, 3: 5, 4: 0}
# error value   :  35.067427257342786
# range:           4736 4768
#
# num iter      :  14600
# train accuracy:  20
# dist          :  {0: 5, 1: 6, 2: 2, 3: 7, 4: 0}
# error value   :  35.60461164184377
# range:           7936 7968
# ============== new learning rate:  0.0014433756729740645
# full accuracy :  6513
# dist          :  {0: 1949, 1: 1682, 2: 1275, 3: 1607, 4: 0}
# max train accuracy :  6513
#
# num iter      :  14700
# train accuracy:  24
# dist          :  {0: 6, 1: 8, 2: 5, 3: 5, 4: 0}
# error value   :  35.15657255319212
# range:           1152 1184
#
# num iter      :  14800
# train accuracy:  17
# dist          :  {0: 6, 1: 4, 2: 6, 3: 1, 4: 0}
# error value   :  35.299335583905
# range:           4352 4384
#
# num iter      :  14900
# train accuracy:  16
# dist          :  {0: 3, 1: 4, 2: 3, 3: 6, 4: 0}
# error value   :  35.97366864309926
# range:           7552 7584
# ============== new learning rate:  0.0014285714285714286
# full accuracy :  6516
# dist          :  {0: 1949, 1: 1684, 2: 1275, 3: 1608, 4: 0}
# max train accuracy :  6516
#
# num iter      :  15000
# train accuracy:  18
# dist          :  {0: 6, 1: 4, 2: 4, 3: 4, 4: 0}
# error value   :  37.036190306795355
# range:           768 800
#
# num iter      :  15100
# train accuracy:  22
# dist          :  {0: 5, 1: 9, 2: 5, 3: 3, 4: 0}
# error value   :  35.34443855199062
# range:           3968 4000
#
# num iter      :  15200
# train accuracy:  21
# dist          :  {0: 7, 1: 6, 2: 4, 3: 4, 4: 0}
# error value   :  35.89675965111599
# range:           7168 7200
# ============== new learning rate:  0.001414213562373095
# full accuracy :  6521
# dist          :  {0: 1949, 1: 1685, 2: 1277, 3: 1610, 4: 0}
# max train accuracy :  6521
#
# num iter      :  15300
# train accuracy:  24
# dist          :  {0: 3, 1: 8, 2: 8, 3: 5, 4: 0}
# error value   :  34.116153616812774
# range:           384 416
#
# num iter      :  15400
# train accuracy:  20
# dist          :  {0: 3, 1: 5, 2: 2, 3: 10, 4: 0}
# error value   :  35.53721213288173
# range:           3584 3616
#
# num iter      :  15500
# train accuracy:  22
# dist          :  {0: 7, 1: 3, 2: 6, 3: 6, 4: 0}
# error value   :  35.30488393517453
# range:           6784 6816
# ============== new learning rate:  0.0014002800840280097
# full accuracy :  6533
# dist          :  {0: 1949, 1: 1688, 2: 1280, 3: 1616, 4: 0}
# max train accuracy :  6533
#
# num iter      :  15600
# train accuracy:  17
# dist          :  {0: 1, 1: 5, 2: 8, 3: 3, 4: 0}
# error value   :  36.111047691446515
# range:           0 32
#
# num iter      :  15700
# train accuracy:  20
# dist          :  {0: 6, 1: 4, 2: 6, 3: 4, 4: 0}
# error value   :  35.014695063945574
# range:           3200 3232
#
# num iter      :  15800
# train accuracy:  21
# dist          :  {0: 6, 1: 4, 2: 6, 3: 5, 4: 0}
# error value   :  36.617144863897025
# range:           6400 6432
#
# num iter      :  15900
# train accuracy:  24
# dist          :  {0: 10, 1: 7, 2: 3, 3: 4, 4: 0}
# error value   :  34.43069300852025
# range:           9600 9632
# ============== new learning rate:  0.001386750490563073
# full accuracy :  6544
# dist          :  {0: 1949, 1: 1692, 2: 1283, 3: 1620, 4: 0}
# max train accuracy :  6544
#
# num iter      :  16000
# train accuracy:  22
# dist          :  {0: 8, 1: 9, 2: 2, 3: 3, 4: 0}
# error value   :  34.36875790906999
# range:           2816 2848
#
# num iter      :  16100
# train accuracy:  21
# dist          :  {0: 6, 1: 4, 2: 1, 3: 10, 4: 0}
# error value   :  37.92948253809262
# range:           6016 6048
#
# num iter      :  16200
# train accuracy:  18
# dist          :  {0: 6, 1: 3, 2: 4, 3: 5, 4: 0}
# error value   :  36.94061084126806
# range:           9216 9248
# ============== new learning rate:  0.0013736056394868903
# full accuracy :  6549
# dist          :  {0: 1949, 1: 1694, 2: 1285, 3: 1621, 4: 0}
# max train accuracy :  6549
#
# num iter      :  16300
# train accuracy:  21
# dist          :  {0: 5, 1: 2, 2: 6, 3: 8, 4: 0}
# error value   :  35.207327173565886
# range:           2432 2464
#
# num iter      :  16400
# train accuracy:  20
# dist          :  {0: 5, 1: 7, 2: 3, 3: 5, 4: 0}
# error value   :  34.905984730090736
# range:           5632 5664
#
# num iter      :  16500
# train accuracy:  18
# dist          :  {0: 2, 1: 9, 2: 2, 3: 5, 4: 0}
# error value   :  37.279865623631814
# range:           8832 8864
# ============== new learning rate:  0.0013608276348795435
# full accuracy :  6551
# dist          :  {0: 1948, 1: 1695, 2: 1285, 3: 1623, 4: 0}
# max train accuracy :  6551
#
# num iter      :  16600
# train accuracy:  24
# dist          :  {0: 12, 1: 4, 2: 4, 3: 4, 4: 0}
# error value   :  33.81595988301502
# range:           2048 2080
#
# num iter      :  16700
# train accuracy:  23
# dist          :  {0: 6, 1: 9, 2: 2, 3: 6, 4: 0}
# error value   :  33.903133815334975
# range:           5248 5280
#
# num iter      :  16800
# train accuracy:  24
# dist          :  {0: 9, 1: 3, 2: 6, 3: 6, 4: 0}
# error value   :  35.375579534064805
# range:           8448 8480
# ============== new learning rate:  0.0013483997249264842
# full accuracy :  6550
# dist          :  {0: 1948, 1: 1693, 2: 1286, 3: 1623, 4: 0}
# max train accuracy :  6551
#
# num iter      :  16900
# train accuracy:  22
# dist          :  {0: 9, 1: 5, 2: 2, 3: 6, 4: 0}
# error value   :  35.622404985382744
# range:           1664 1696
#
# num iter      :  17000
# train accuracy:  26
# dist          :  {0: 7, 1: 12, 2: 4, 3: 3, 4: 0}
# error value   :  33.18696375440127
# range:           4864 4896
#
# num iter      :  17100
# train accuracy:  22
# dist          :  {0: 3, 1: 4, 2: 3, 3: 12, 4: 0}
# error value   :  36.87350093527984
# range:           8064 8096
# ============== new learning rate:  0.001336306209562122
# full accuracy :  6554
# dist          :  {0: 1948, 1: 1694, 2: 1287, 3: 1625, 4: 0}
# max train accuracy :  6554
#
# num iter      :  17200
# train accuracy:  21
# dist          :  {0: 7, 1: 5, 2: 5, 3: 4, 4: 0}
# error value   :  35.06253158562461
# range:           1280 1312
#
# num iter      :  17300
# train accuracy:  27
# dist          :  {0: 14, 1: 2, 2: 8, 3: 3, 4: 0}
# error value   :  32.581667177747434
# range:           4480 4512
#
# num iter      :  17400
# train accuracy:  17
# dist          :  {0: 6, 1: 4, 2: 3, 3: 4, 4: 0}
# error value   :  35.871517884515725
# range:           7680 7712
# ============== new learning rate:  0.0013245323570650438
# full accuracy :  6560
# dist          :  {0: 1949, 1: 1694, 2: 1290, 3: 1627, 4: 0}
# max train accuracy :  6560
#
# num iter      :  17500
# train accuracy:  19
# dist          :  {0: 9, 1: 4, 2: 2, 3: 4, 4: 0}
# error value   :  35.712876969027505
# range:           896 928
#
# num iter      :  17600
# train accuracy:  21
# dist          :  {0: 6, 1: 3, 2: 4, 3: 8, 4: 0}
# error value   :  38.46709028029749
# range:           4096 4128
#
# num iter      :  17700
# train accuracy:  17
# dist          :  {0: 6, 1: 7, 2: 3, 3: 1, 4: 0}
# error value   :  35.02776996451411
# range:           7296 7328
# ============== new learning rate:  0.0013130643285972255
# full accuracy :  6570
# dist          :  {0: 1949, 1: 1695, 2: 1300, 3: 1626, 4: 0}
# max train accuracy :  6570
#
# num iter      :  17800
# train accuracy:  19
# dist          :  {0: 10, 1: 4, 2: 4, 3: 1, 4: 0}
# error value   :  36.83100008286817
# range:           512 544
#
# num iter      :  17900
# train accuracy:  20
# dist          :  {0: 8, 1: 2, 2: 4, 3: 6, 4: 0}
# error value   :  36.98667850211541
# range:           3712 3744
#
# num iter      :  18000
# train accuracy:  20
# dist          :  {0: 7, 1: 6, 2: 3, 3: 4, 4: 0}
# error value   :  36.103470759549886
# range:           6912 6944
# ============== new learning rate:  0.0013018891098082388
# full accuracy :  6576
# dist          :  {0: 1950, 1: 1699, 2: 1303, 3: 1624, 4: 0}
# max train accuracy :  6576
#
# num iter      :  18100
# train accuracy:  23
# dist          :  {0: 5, 1: 9, 2: 3, 3: 6, 4: 0}
# error value   :  34.23969724223806
# range:           128 160
#
# num iter      :  18200
# train accuracy:  25
# dist          :  {0: 9, 1: 5, 2: 6, 3: 5, 4: 0}
# error value   :  33.89959619200836
# range:           3328 3360
#
# num iter      :  18300
# train accuracy:  26
# dist          :  {0: 5, 1: 9, 2: 5, 3: 7, 4: 0}
# error value   :  34.415201198867116
# range:           6528 6560
#
# num iter      :  18400
# train accuracy:  23
# dist          :  {0: 6, 1: 11, 2: 4, 3: 2, 4: 0}
# error value   :  34.12044041337589
# range:           9728 9760
# ============== new learning rate:  0.0012909944487358056
# full accuracy :  6578
# dist          :  {0: 1950, 1: 1698, 2: 1304, 3: 1626, 4: 0}
# max train accuracy :  6578
#
# num iter      :  18500
# train accuracy:  15
# dist          :  {0: 4, 1: 4, 2: 5, 3: 2, 4: 0}
# error value   :  37.53426034019042
# range:           2944 2976
#
# num iter      :  18600
# train accuracy:  19
# dist          :  {0: 6, 1: 1, 2: 5, 3: 7, 4: 0}
# error value   :  36.98089440553036
# range:           6144 6176
#
# num iter      :  18700
# train accuracy:  20
# dist          :  {0: 3, 1: 5, 2: 5, 3: 7, 4: 0}
# error value   :  35.0687583879727
# range:           9344 9376
# ============== new learning rate:  0.0012803687993289598
# full accuracy :  6584
# dist          :  {0: 1950, 1: 1699, 2: 1308, 3: 1627, 4: 0}
# max train accuracy :  6584
#
# num iter      :  18800
# train accuracy:  21
# dist          :  {0: 5, 1: 8, 2: 3, 3: 5, 4: 0}
# error value   :  35.796463827510436
# range:           2560 2592
#
# num iter      :  18900
# train accuracy:  23
# dist          :  {0: 8, 1: 4, 2: 3, 3: 8, 4: 0}
# error value   :  34.73375534312131
# range:           5760 5792
#
# num iter      :  19000
# train accuracy:  23
# dist          :  {0: 5, 1: 11, 2: 3, 3: 4, 4: 0}
# error value   :  35.36979191812008
# range:           8960 8992
# ============== new learning rate:  0.001270001270001905
# full accuracy :  6593
# dist          :  {0: 1950, 1: 1702, 2: 1310, 3: 1631, 4: 0}
# max train accuracy :  6593
#
# num iter      :  19100
# train accuracy:  22
# dist          :  {0: 3, 1: 4, 2: 6, 3: 9, 4: 0}
# error value   :  34.70837012232536
# range:           2176 2208
#
# num iter      :  19200
# train accuracy:  19
# dist          :  {0: 7, 1: 4, 2: 4, 3: 4, 4: 0}
# error value   :  35.59609281311397
# range:           5376 5408
#
# num iter      :  19300
# train accuracy:  21
# dist          :  {0: 10, 1: 4, 2: 2, 3: 5, 4: 0}
# error value   :  34.84132015093644
# range:           8576 8608
# ============== new learning rate:  0.001259881576697424
# full accuracy :  6597
# dist          :  {0: 1950, 1: 1703, 2: 1312, 3: 1632, 4: 0}
# max train accuracy :  6597
#
# num iter      :  19400
# train accuracy:  19
# dist          :  {0: 7, 1: 5, 2: 5, 3: 2, 4: 0}
# error value   :  36.3186563004159
# range:           1792 1824
#
# num iter      :  19500
# train accuracy:  21
# dist          :  {0: 5, 1: 5, 2: 5, 3: 6, 4: 0}
# error value   :  35.11615591473019
# range:           4992 5024
#
# num iter      :  19600
# train accuracy:  21
# dist          :  {0: 5, 1: 10, 2: 3, 3: 3, 4: 0}
# error value   :  34.21968167898679
# range:           8192 8224
# ============== new learning rate:  0.00125
# full accuracy :  6602
# dist          :  {0: 1950, 1: 1704, 2: 1315, 3: 1633, 4: 0}
# max train accuracy :  6602
#
# num iter      :  19700
# train accuracy:  17
# dist          :  {0: 6, 1: 2, 2: 2, 3: 7, 4: 0}
# error value   :  38.13778458406479
# range:           1408 1440
#
# num iter      :  19800
# train accuracy:  22
# dist          :  {0: 11, 1: 6, 2: 3, 3: 2, 4: 0}
# error value   :  35.315255905557514
# range:           4608 4640
#
# num iter      :  19900
# train accuracy:  25
# dist          :  {0: 10, 1: 5, 2: 2, 3: 8, 4: 0}
# error value   :  33.82409096935279
# range:           7808 7840
# ============== new learning rate:  0.0012403473458920847
# full accuracy :  6611
# dist          :  {0: 1951, 1: 1708, 2: 1318, 3: 1634, 4: 0}
# max train accuracy :  6611
#
# num iter      :  20000
# train accuracy:  21
# dist          :  {0: 5, 1: 7, 2: 3, 3: 6, 4: 0}
# error value   :  36.309727519485875
# range:           1024 1056
#
# num iter      :  20100
# train accuracy:  20
# dist          :  {0: 3, 1: 9, 2: 4, 3: 4, 4: 0}
# error value   :  34.21330241195291
# range:           4224 4256
#
# num iter      :  20200
# train accuracy:  21
# dist          :  {0: 3, 1: 7, 2: 4, 3: 7, 4: 0}
# error value   :  35.55844613066706
# range:           7424 7456
# ============== new learning rate:  0.0012309149097933273
# full accuracy :  6618
# dist          :  {0: 1952, 1: 1709, 2: 1319, 3: 1638, 4: 0}
# max train accuracy :  6618
#
# num iter      :  20300
# train accuracy:  23
# dist          :  {0: 9, 1: 9, 2: 2, 3: 3, 4: 0}
# error value   :  34.01589253972656
# range:           640 672
#
# num iter      :  20400
# train accuracy:  20
# dist          :  {0: 7, 1: 1, 2: 5, 3: 7, 4: 0}
# error value   :  36.261805644642095
# range:           3840 3872
#
# num iter      :  20500
# train accuracy:  20
# dist          :  {0: 6, 1: 6, 2: 4, 3: 4, 4: 0}
# error value   :  34.29854936901377
# range:           7040 7072
# ============== new learning rate:  0.0012216944435630521
# full accuracy :  6625
# dist          :  {0: 1952, 1: 1713, 2: 1322, 3: 1638, 4: 0}
# max train accuracy :  6625
#
# num iter      :  20600
# train accuracy:  23
# dist          :  {0: 4, 1: 11, 2: 3, 3: 5, 4: 0}
# error value   :  35.93931860609361
# range:           256 288
#
# num iter      :  20700
# train accuracy:  22
# dist          :  {0: 9, 1: 5, 2: 2, 3: 6, 4: 0}
# error value   :  36.05952914358007
# range:           3456 3488
#
# num iter      :  20800
# train accuracy:  22
# dist          :  {0: 4, 1: 5, 2: 4, 3: 9, 4: 0}
# error value   :  34.02975202605286
# range:           6656 6688
#
# num iter      :  20900
# train accuracy:  22
# dist          :  {0: 2, 1: 8, 2: 5, 3: 7, 4: 0}
# error value   :  36.07608204497545
# range:           9856 9888
# ============== new learning rate:  0.001212678125181665
# full accuracy :  6634
# dist          :  {0: 1953, 1: 1717, 2: 1325, 3: 1639, 4: 0}
# max train accuracy :  6634
#
# num iter      :  21000
# train accuracy:  20
# dist          :  {0: 4, 1: 4, 2: 3, 3: 9, 4: 0}
# error value   :  37.13455577285041
# range:           3072 3104
#
# num iter      :  21100
# train accuracy:  23
# dist          :  {0: 4, 1: 11, 2: 3, 3: 5, 4: 0}
# error value   :  34.08798964141531
# range:           6272 6304
#
# num iter      :  21200
# train accuracy:  22
# dist          :  {0: 11, 1: 5, 2: 3, 3: 3, 4: 0}
# error value   :  34.659323118908404
# range:           9472 9504
# ============== new learning rate:  0.001203858530857692
# full accuracy :  6637
# dist          :  {0: 1953, 1: 1718, 2: 1327, 3: 1639, 4: 0}
# max train accuracy :  6637
#
# num iter      :  21300
# train accuracy:  20
# dist          :  {0: 4, 1: 6, 2: 6, 3: 4, 4: 0}
# error value   :  33.95095497991418
# range:           2688 2720
#
# num iter      :  21400
# train accuracy:  24
# dist          :  {0: 6, 1: 6, 2: 1, 3: 11, 4: 0}
# error value   :  36.94404560205875
# range:           5888 5920
#
# num iter      :  21500
# train accuracy:  26
# dist          :  {0: 6, 1: 3, 2: 10, 3: 7, 4: 0}
# error value   :  35.12799380626549
# range:           9088 9120
# ============== new learning rate:  0.0011952286093343937
# full accuracy :  6639
# dist          :  {0: 1953, 1: 1718, 2: 1330, 3: 1638, 4: 0}
# max train accuracy :  6639
#
# num iter      :  21600
# train accuracy:  25
# dist          :  {0: 10, 1: 2, 2: 6, 3: 7, 4: 0}
# error value   :  35.12387278940663
# range:           2304 2336
#
# num iter      :  21700
# train accuracy:  16
# dist          :  {0: 5, 1: 4, 2: 3, 3: 4, 4: 0}
# error value   :  36.52789456524468
# range:           5504 5536
#
# num iter      :  21800
# train accuracy:  21
# dist          :  {0: 4, 1: 9, 2: 4, 3: 4, 4: 0}
# error value   :  36.37879424006125
# range:           8704 8736
# ============== new learning rate:  0.0011867816581938532
# full accuracy :  6643
# dist          :  {0: 1954, 1: 1717, 2: 1332, 3: 1640, 4: 0}
# max train accuracy :  6643
#
# num iter      :  21900
# train accuracy:  22
# dist          :  {0: 4, 1: 4, 2: 7, 3: 7, 4: 0}
# error value   :  35.38405728592284
# range:           1920 1952
#
# num iter      :  22000
# train accuracy:  14
# dist          :  {0: 8, 1: 2, 2: 1, 3: 3, 4: 0}
# error value   :  35.03015282638356
# range:           5120 5152
#
# num iter      :  22100
# train accuracy:  20
# dist          :  {0: 5, 1: 5, 2: 7, 3: 3, 4: 0}
# error value   :  34.22994688573713
# range:           8320 8352
# ============== new learning rate:  0.0011785113019775794
# full accuracy :  6644
# dist          :  {0: 1954, 1: 1715, 2: 1334, 3: 1641, 4: 0}
# max train accuracy :  6644
#
# num iter      :  22200
# train accuracy:  15
# dist          :  {0: 2, 1: 6, 2: 3, 3: 4, 4: 0}
# error value   :  37.94254938311878
# range:           1536 1568
#
# num iter      :  22300
# train accuracy:  19
# dist          :  {0: 6, 1: 3, 2: 5, 3: 5, 4: 0}
# error value   :  34.5241605215193
# range:           4736 4768
#
# num iter      :  22400
# train accuracy:  20
# dist          :  {0: 5, 1: 6, 2: 2, 3: 7, 4: 0}
# error value   :  35.59186422608837
# range:           7936 7968
# ============== new learning rate:  0.0011704114719613059
# full accuracy :  6654
# dist          :  {0: 1953, 1: 1717, 2: 1339, 3: 1645, 4: 0}
# max train accuracy :  6654
#
# num iter      :  22500
# train accuracy:  24
# dist          :  {0: 6, 1: 8, 2: 5, 3: 5, 4: 0}
# error value   :  34.68097079779195
# range:           1152 1184
#
# num iter      :  22600
# train accuracy:  17
# dist          :  {0: 6, 1: 4, 2: 6, 3: 1, 4: 0}
# error value   :  34.944850936699844
# range:           4352 4384
#
# num iter      :  22700
# train accuracy:  17
# dist          :  {0: 3, 1: 4, 2: 4, 3: 6, 4: 0}
# error value   :  35.37409633431962
# range:           7552 7584
# ============== new learning rate:  0.0011624763874381928
# full accuracy :  6667
# dist          :  {0: 1953, 1: 1715, 2: 1348, 3: 1651, 4: 0}
# max train accuracy :  6667
#
# num iter      :  22800
# train accuracy:  20
# dist          :  {0: 6, 1: 3, 2: 7, 3: 4, 4: 0}
# error value   :  36.50758348233942
# range:           768 800
#
# num iter      :  22900
# train accuracy:  23
# dist          :  {0: 5, 1: 10, 2: 5, 3: 3, 4: 0}
# error value   :  34.48938425583661
# range:           3968 4000
#
# num iter      :  23000
# train accuracy:  21
# dist          :  {0: 7, 1: 6, 2: 4, 3: 4, 4: 0}
# error value   :  35.45558451152245
# range:           7168 7200
# ============== new learning rate:  0.0011547005383792514
# full accuracy :  6671
# dist          :  {0: 1954, 1: 1717, 2: 1348, 3: 1652, 4: 0}
# max train accuracy :  6671
#
# num iter      :  23100
# train accuracy:  24
# dist          :  {0: 3, 1: 8, 2: 8, 3: 5, 4: 0}
# error value   :  33.727224312731934
# range:           384 416
#
# num iter      :  23200
# train accuracy:  22
# dist          :  {0: 3, 1: 6, 2: 3, 3: 10, 4: 0}
# error value   :  35.23480237633551
# ...
# error value   :  34.10266520229149
# range:           1664 1696
#
# num iter      :  48200
# train accuracy:  26
# dist          :  {0: 7, 1: 12, 2: 4, 3: 3, 4: 0}
# error value   :  31.779696932221764
# range:           4864 4896
#
# num iter      :  48300
# train accuracy:  23
# dist          :  {0: 3, 1: 4, 2: 4, 3: 12, 4: 0}
# error value   :  36.029022772269386
# range:           8064 8096
# ============== new learning rate:  0.0008006407690254357
# full accuracy :  6936
# dist          :  {0: 1944, 1: 1755, 2: 1478, 3: 1759, 4: 0}
# max train accuracy :  6936
#
# num iter      :  48400
# train accuracy:  22
# dist          :  {0: 7, 1: 5, 2: 5, 3: 5, 4: 0}
# error value   :  33.90013179584483
# range:           1280 1312
#
# num iter      :  48500
# train accuracy:  27
# dist          :  {0: 14, 1: 3, 2: 7, 3: 3, 4: 0}
# error value   :  31.8298562125517
# range:           4480 4512
#
# num iter      :  48600
# train accuracy:  20
# dist          :  {0: 6, 1: 5, 2: 4, 3: 5, 4: 0}
# error value   :  34.61837883274985
# range:           7680 7712
# ============== new learning rate:  0.0007980868844676221
# full accuracy :  6939
# dist          :  {0: 1944, 1: 1756, 2: 1480, 3: 1759, 4: 0}
# max train accuracy :  6939
#
# num iter      :  48700
# train accuracy:  17
# dist          :  {0: 8, 1: 4, 2: 2, 3: 3, 4: 0}
# error value   :  35.2799876700968
# range:           896 928
#
# num iter      :  48800
# train accuracy:  23
# dist          :  {0: 7, 1: 3, 2: 5, 3: 8, 4: 0}
# error value   :  36.75555955159593
# range:           4096 4128
#
# num iter      :  48900
# train accuracy:  18
# dist          :  {0: 7, 1: 7, 2: 3, 3: 1, 4: 0}
# error value   :  33.764545351359445
# range:           7296 7328
# ============== new learning rate:  0.00079555728417573
# full accuracy :  6942
# dist          :  {0: 1944, 1: 1757, 2: 1482, 3: 1759, 4: 0}
# max train accuracy :  6942
#
# num iter      :  49000
# train accuracy:  20
# dist          :  {0: 10, 1: 5, 2: 4, 3: 1, 4: 0}
# error value   :  35.50455409095673
# range:           512 544
#
# num iter      :  49100
# train accuracy:  20
# dist          :  {0: 8, 1: 3, 2: 3, 3: 6, 4: 0}
# error value   :  36.334857245867425
# range:           3712 3744
#
# num iter      :  49200
# train accuracy:  19
# dist          :  {0: 7, 1: 6, 2: 3, 3: 3, 4: 0}
# error value   :  36.070344375152395
# range:           6912 6944
# ============== new learning rate:  0.0007930515857181441
# full accuracy :  6944
# dist          :  {0: 1944, 1: 1757, 2: 1484, 3: 1759, 4: 0}
# max train accuracy :  6944
#
# num iter      :  49300
# train accuracy:  22
# dist          :  {0: 5, 1: 9, 2: 3, 3: 5, 4: 0}
# error value   :  33.31342049064059
# range:           128 160
#
# num iter      :  49400
# train accuracy:  25
# dist          :  {0: 10, 1: 5, 2: 5, 3: 5, 4: 0}
# error value   :  32.48963149890385
# range:           3328 3360
#
# num iter      :  49500
# train accuracy:  29
# dist          :  {0: 5, 1: 10, 2: 7, 3: 7, 4: 0}
# error value   :  32.426168397077
# range:           6528 6560
#
# num iter      :  49600
# train accuracy:  24
# dist          :  {0: 6, 1: 11, 2: 5, 3: 2, 4: 0}
# error value   :  33.18380225670846
# range:           9728 9760
# ============== new learning rate:  0.0007905694150420948
# full accuracy :  6946
# dist          :  {0: 1944, 1: 1757, 2: 1484, 3: 1761, 4: 0}
# max train accuracy :  6946
#
# num iter      :  49700
# train accuracy:  15
# dist          :  {0: 4, 1: 4, 2: 5, 3: 2, 4: 0}
# error value   :  36.469889420849505
# range:           2944 2976
#
# num iter      :  49800
# train accuracy:  19
# dist          :  {0: 6, 1: 1, 2: 6, 3: 6, 4: 0}
# error value   :  35.66290947036107
# range:           6144 6176
#
# num iter      :  49900
# train accuracy:  19
# dist          :  {0: 3, 1: 5, 2: 5, 3: 6, 4: 0}
# error value   :  34.23761860260071
# range:           9344 9376
# ============== new learning rate:  0.0007881104062391007
# full accuracy :  6947
# dist          :  {0: 1944, 1: 1758, 2: 1484, 3: 1761, 4: 0}
# max train accuracy :  6947
#
# num iter      :  50000
# train accuracy:  21
# dist          :  {0: 5, 1: 8, 2: 3, 3: 5, 4: 0}
# error value   :  34.688775585514605
# range:           2560 2592
#
# num iter      :  50100
# train accuracy:  27
# dist          :  {0: 8, 1: 5, 2: 4, 3: 10, 4: 0}
# error value   :  33.054017991275416
# range:           5760 5792
#
# num iter      :  50200
# train accuracy:  23
# dist          :  {0: 5, 1: 11, 2: 3, 3: 4, 4: 0}
# error value   :  34.54155967521827
# range:           8960 8992
# ============== new learning rate:  0.0007856742013183862
# full accuracy :  6952
# dist          :  {0: 1944, 1: 1758, 2: 1486, 3: 1764, 4: 0}
# max train accuracy :  6952
#
# num iter      :  50300
# train accuracy:  24
# dist          :  {0: 3, 1: 6, 2: 5, 3: 10, 4: 0}
# error value   :  33.73844983797075
# range:           2176 2208
#
# num iter      :  50400
# train accuracy:  17
# dist          :  {0: 7, 1: 4, 2: 3, 3: 3, 4: 0}
# error value   :  35.10067564673091
# range:           5376 5408
#
# num iter      :  50500
# train accuracy:  22
# dist          :  {0: 10, 1: 4, 2: 2, 3: 6, 4: 0}
# error value   :  34.83557232457847
# range:           8576 8608
# ============== new learning rate:  0.0007832604499879574
# full accuracy :  6956
# dist          :  {0: 1944, 1: 1761, 2: 1487, 3: 1764, 4: 0}
# max train accuracy :  6956
#
# num iter      :  50600
# train accuracy:  21
# dist          :  {0: 7, 1: 6, 2: 5, 3: 3, 4: 0}
# error value   :  34.657219487167225
# range:           1792 1824
#
# num iter      :  50700
# train accuracy:  25
# dist          :  {0: 5, 1: 5, 2: 6, 3: 9, 4: 0}
# error value   :  33.862996289004
# range:           4992 5024
#
# num iter      :  50800
# train accuracy:  22
# dist          :  {0: 6, 1: 10, 2: 3, 3: 3, 4: 0}
# error value   :  33.13569625748917
# range:           8192 8224
# ============== new learning rate:  0.0007808688094430304
# full accuracy :  6961
# dist          :  {0: 1944, 1: 1763, 2: 1489, 3: 1765, 4: 0}
# max train accuracy :  6961
#
# num iter      :  50900
# train accuracy:  17
# dist          :  {0: 6, 1: 4, 2: 2, 3: 5, 4: 0}
# error value   :  36.83370427740924
# range:           1408 1440
#
# num iter      :  51000
# train accuracy:  23
# dist          :  {0: 11, 1: 7, 2: 2, 3: 3, 4: 0}
# error value   :  33.44046684529056
# range:           4608 4640
#
# num iter      :  51100
# train accuracy:  25
# dist          :  {0: 10, 1: 5, 2: 2, 3: 8, 4: 0}
# error value   :  32.68436784902957
# range:           7808 7840
# ============== new learning rate:  0.0007784989441615229
# full accuracy :  6963
# dist          :  {0: 1944, 1: 1766, 2: 1488, 3: 1765, 4: 0}
# max train accuracy :  6963
#
# num iter      :  51200
# train accuracy:  22
# dist          :  {0: 5, 1: 8, 2: 3, 3: 6, 4: 0}
# error value   :  34.84492545825611
# range:           1024 1056
#
# num iter      :  51300
# train accuracy:  19
# dist          :  {0: 3, 1: 8, 2: 4, 3: 4, 4: 0}
# error value   :  33.618807272569285
# range:           4224 4256
#
# num iter      :  51400
# train accuracy:  21
# dist          :  {0: 3, 1: 7, 2: 4, 3: 7, 4: 0}
# error value   :  34.66198073678709
# range:           7424 7456
# ============== new learning rate:  0.0007761505257063328
# full accuracy :  6967
# dist          :  {0: 1944, 1: 1767, 2: 1490, 3: 1766, 4: 0}
# max train accuracy :  6967
#
# num iter      :  51500
# train accuracy:  24
# dist          :  {0: 9, 1: 10, 2: 2, 3: 3, 4: 0}
# error value   :  32.54306731403382
# range:           640 672
#
# num iter      :  51600
# train accuracy:  20
# dist          :  {0: 7, 1: 1, 2: 4, 3: 8, 4: 0}
# error value   :  35.55552193728019
# range:           3840 3872
#
# num iter      :  51700
# train accuracy:  22
# dist          :  {0: 6, 1: 6, 2: 6, 3: 4, 4: 0}
# error value   :  32.694241813182806
# range:           7040 7072
# ============== new learning rate:  0.0007738232325341369
# full accuracy :  6972
# dist          :  {0: 1944, 1: 1769, 2: 1493, 3: 1766, 4: 0}
# max train accuracy :  6972
#
# num iter      :  51800
# train accuracy:  24
# dist          :  {0: 4, 1: 11, 2: 4, 3: 5, 4: 0}
# error value   :  35.311044655809
# range:           256 288
#
# num iter      :  51900
# train accuracy:  24
# dist          :  {0: 9, 1: 5, 2: 4, 3: 6, 4: 0}
# error value   :  35.01656006252417
# range:           3456 3488
#
# num iter      :  52000
# train accuracy:  25
# dist          :  {0: 5, 1: 5, 2: 5, 3: 10, 4: 0}
# error value   :  32.60619765791306
# range:           6656 6688
#
# num iter      :  52100
# train accuracy:  23
# dist          :  {0: 2, 1: 9, 2: 5, 3: 7, 4: 0}
# error value   :  35.21264242076869
# range:           9856 9888
# ============== new learning rate:  0.0007715167498104596
# full accuracy :  6973
# dist          :  {0: 1944, 1: 1768, 2: 1495, 3: 1766, 4: 0}
# max train accuracy :  6973
#
# num iter      :  52200
# train accuracy:  21
# dist          :  {0: 4, 1: 4, 2: 3, 3: 10, 4: 0}
# error value   :  35.53902777158703
# range:           3072 3104
#
# num iter      :  52300
# train accuracy:  24
# dist          :  {0: 4, 1: 9, 2: 5, 3: 6, 4: 0}
# error value   :  33.21240818744102
# range:           6272 6304
#
# num iter      :  52400
# train accuracy:  24
# dist          :  {0: 12, 1: 5, 2: 4, 3: 3, 4: 0}
# error value   :  32.79643774026713
# range:           9472 9504
# ============== new learning rate:  0.0007692307692307692
# full accuracy :  6976
# dist          :  {0: 1944, 1: 1768, 2: 1497, 3: 1767, 4: 0}
# max train accuracy :  6976
#
# num iter      :  52500
# train accuracy:  21
# dist          :  {0: 4, 1: 7, 2: 6, 3: 4, 4: 0}
# error value   :  33.07944922636354
# range:           2688 2720
#
# num iter      :  52600
# train accuracy:  25
# dist          :  {0: 6, 1: 6, 2: 1, 3: 12, 4: 0}
# error value   :  35.85139943395403
# range:           5888 5920
#
# num iter      :  52700
# train accuracy:  24
# dist          :  {0: 6, 1: 1, 2: 10, 3: 7, 4: 0}
# error value   :  34.252123036078345
# range:           9088 9120
# ============== new learning rate:  0.0007669649888473704
# full accuracy :  6977
# dist          :  {0: 1944, 1: 1769, 2: 1497, 3: 1767, 4: 0}
# max train accuracy :  6977
#
# num iter      :  52800
# train accuracy:  25
# dist          :  {0: 10, 1: 2, 2: 6, 3: 7, 4: 0}
# error value   :  33.547245140164065
# range:           2304 2336
#
# num iter      :  52900
# train accuracy:  19
# dist          :  {0: 5, 1: 6, 2: 4, 3: 4, 4: 0}
# error value   :  35.04803444764915
# range:           5504 5536
#
# num iter      :  53000
# train accuracy:  23
# dist          :  {0: 4, 1: 9, 2: 6, 3: 4, 4: 0}
# error value   :  34.3320110652121
# range:           8704 8736
# ============== new learning rate:  0.0007647191129018725
# full accuracy :  6982
# dist          :  {0: 1945, 1: 1769, 2: 1500, 3: 1768, 4: 0}
# max train accuracy :  6982
#
# num iter      :  53100
# train accuracy:  25
# dist          :  {0: 4, 1: 4, 2: 10, 3: 7, 4: 0}
# error value   :  34.63852117016064
# range:           1920 1952
#
# num iter      :  53200
# train accuracy:  17
# dist          :  {0: 8, 1: 2, 2: 4, 3: 3, 4: 0}
# error value   :  33.90247737057855
# range:           5120 5152
#
# num iter      :  53300
# train accuracy:  22
# dist          :  {0: 5, 1: 7, 2: 7, 3: 3, 4: 0}
# error value   :  32.86860023816669
# range:           8320 8352
# ============== new learning rate:  0.0007624928516630233
# full accuracy :  6989
# dist          :  {0: 1945, 1: 1772, 2: 1502, 3: 1770, 4: 0}
# max train accuracy :  6989
#
# num iter      :  53400
# train accuracy:  17
# dist          :  {0: 2, 1: 6, 2: 3, 3: 6, 4: 0}
# error value   :  35.42116989068269
# range:           1536 1568
#
# num iter      :  53500
# train accuracy:  20
# dist          :  {0: 6, 1: 3, 2: 6, 3: 5, 4: 0}
# error value   :  33.29364377658058
# range:           4736 4768
#
# num iter      :  53600
# train accuracy:  21
# dist          :  {0: 5, 1: 6, 2: 3, 3: 7, 4: 0}
# error value   :  34.68424340316454
# range:           7936 7968
# ============== new learning rate:  0.0007602859212697056
# full accuracy :  6992
# dist          :  {0: 1945, 1: 1774, 2: 1502, 3: 1771, 4: 0}
# max train accuracy :  6992
#
# num iter      :  53700
# train accuracy:  23
# dist          :  {0: 6, 1: 8, 2: 5, 3: 4, 4: 0}
# error value   :  33.62804841845446
# range:           1152 1184
#
# num iter      :  53800
# train accuracy:  17
# dist          :  {0: 6, 1: 4, 2: 6, 3: 1, 4: 0}
# error value   :  34.172821782102666
# range:           4352 4384
#
# num iter      :  53900
# train accuracy:  19
# dist          :  {0: 3, 1: 5, 2: 5, 3: 6, 4: 0}
# error value   :  34.70291208444998
# range:           7552 7584
# ============== new learning rate:  0.0007580980435789034
# full accuracy :  6996
# dist          :  {0: 1946, 1: 1773, 2: 1504, 3: 1773, 4: 0}
# max train accuracy :  6996
#
# num iter      :  54000
# train accuracy:  23
# dist          :  {0: 6, 1: 4, 2: 9, 3: 4, 4: 0}
# error value   :  34.45579128225621
# range:           768 800
#
# num iter      :  54100
# train accuracy:  25
# dist          :  {0: 5, 1: 10, 2: 7, 3: 3, 4: 0}
# error value   :  32.581085803021566
# range:           3968 4000
#
# num iter      :  54200
# train accuracy:  21
# dist          :  {0: 7, 1: 6, 2: 4, 3: 4, 4: 0}
# error value   :  34.76016561422622
# range:           7168 7200
# ============== new learning rate:  0.0007559289460184544
# full accuracy :  7002
# dist          :  {0: 1946, 1: 1773, 2: 1508, 3: 1775, 4: 0}
# max train accuracy :  7002
#
# num iter      :  54300
# train accuracy:  24
# dist          :  {0: 3, 1: 8, 2: 8, 3: 5, 4: 0}
# error value   :  32.375518817889045
# range:           384 416
#
# num iter      :  54400
# train accuracy:  22
# dist          :  {0: 3, 1: 6, 2: 3, 3: 10, 4: 0}
# error value   :  34.26570360709838
# range:           3584 3616
#
# num iter      :  54500
# train accuracy:  23
# dist          :  {0: 8, 1: 4, 2: 5, 3: 6, 4: 0}
# error value   :  33.53409001759069
# range:           6784 6816
# ============== new learning rate:  0.0007537783614444091
# full accuracy :  7007
# dist          :  {0: 1946, 1: 1773, 2: 1511, 3: 1777, 4: 0}
# max train accuracy :  7007
#
# num iter      :  54600
# train accuracy:  20
# dist          :  {0: 1, 1: 6, 2: 9, 3: 4, 4: 0}
# error value   :  34.19734348531818
# range:           0 32
#
# num iter      :  54700
# train accuracy:  23
# dist          :  {0: 6, 1: 7, 2: 6, 3: 4, 4: 0}
# error value   :  32.59949239312301
# range:           3200 3232
#
# num iter      :  54800
# train accuracy:  23
# dist          :  {0: 6, 1: 4, 2: 7, 3: 6, 4: 0}
# error value   :  35.20176769185603
# range:           6400 6432
#
# num iter      :  54900
# train accuracy:  25
# dist          :  {0: 10, 1: 8, 2: 4, 3: 3, 4: 0}
# error value   :  32.874311306892935
# range:           9600 9632
# ============== new learning rate:  0.0007516460280028289
# full accuracy :  7012
# dist          :  {0: 1946, 1: 1774, 2: 1513, 3: 1779, 4: 0}
# max train accuracy :  7012
#
# num iter      :  55000
# train accuracy:  24
# dist          :  {0: 8, 1: 9, 2: 4, 3: 3, 4: 0}
# error value   :  33.077090890765604
# range:           2816 2848
#
# num iter      :  55100
# train accuracy:  22
# dist          :  {0: 6, 1: 4, 2: 1, 3: 11, 4: 0}
# error value   :  36.73596256898456
# range:           6016 6048
#
# num iter      :  55200
# train accuracy:  21
# dist          :  {0: 7, 1: 4, 2: 4, 3: 6, 4: 0}
# error value   :  34.6247447167265
# range:           9216 9248
# ============== new learning rate:  0.0007495316889958615
# full accuracy :  7016
# dist          :  {0: 1945, 1: 1775, 2: 1515, 3: 1781, 4: 0}
# max train accuracy :  7016
#
# num iter      :  55300
# train accuracy:  22
# dist          :  {0: 5, 1: 2, 2: 7, 3: 8, 4: 0}
# error value   :  33.530449976962956
# range:           2432 2464
#
# num iter      :  55400
# train accuracy:  24
# dist          :  {0: 5, 1: 7, 2: 5, 3: 7, 4: 0}
# error value   :  33.38949180510829
# range:           5632 5664
#
# num iter      :  55500
# train accuracy:  20
# dist          :  {0: 2, 1: 10, 2: 2, 3: 6, 4: 0}
# error value   :  35.226156125106776
# range:           8832 8864
# ============== new learning rate:  0.0007474350927519359
# full accuracy :  7017
# dist          :  {0: 1945, 1: 1775, 2: 1516, 3: 1781, 4: 0}
# max train accuracy :  7017
#
# num iter      :  55600
# train accuracy:  25
# dist          :  {0: 12, 1: 4, 2: 5, 3: 4, 4: 0}
# error value   :  33.27684768621817
# range:           2048 2080
#
# num iter      :  55700
# train accuracy:  23
# dist          :  {0: 6, 1: 9, 2: 2, 3: 6, 4: 0}
# error value   :  32.69109906577343
# range:           5248 5280
#
# num iter      :  55800
# train accuracy:  24
# dist          :  {0: 9, 1: 3, 2: 6, 3: 6, 4: 0}
# error value   :  33.501033003574065
# range:           8448 8480
# ============== new learning rate:  0.0007453559924999299

# %% [markdown]
# ##### JUNK: Explanation of Matrix Multiplications

# %%
#             for perceptron in range(0, hidden_layer_list[layer]):
#                     y_out                 = output_list[example_index][layer][perceptron]
#                     if layer == 0:
#                         local_grad_t      = y_out*(1-y_out)*x_train[example_index]
#                     else:
#                         local_grad_t      = y_out*(1-y_out)*output_list[example_index][layer-1]
                        
#                     grad_para_t[layer][perceptron]             =  local_grad_t*sum_para_ary[perceptron]
#                     list_parameter_matrix[layer][perceptron]  -=  grad_para_t[layer][perceptron]*learning_rate
                    
#                     local_grad_x                               =  y_out*(1-y_out)*old_para_matrix[layer][perceptron]
#                     grad_para_x[layer][perceptron]             =  local_grad_x*sum_para_ary[perceptron]
                    
#                    sum_para_ary           = grad_para_x[layer+1][:,para_index_forward_layer].sum()  # column vector read as a row vector
                
#                 for para_index in range(0, num_para_hidLay_list[layer]):
#                     y_out                                     = output_list[example_index][layer][perceptron]
#                     if layer == 0:
#                         x_in                                  = x_train[example_index][para_index]
#                     else:
#                         x_in                                  = output_list[example_index][layer-1][para_index]
#                     local_grad_t                              = y_out*(1-y_out)*x_in
#                     grad_para_t[layer][perceptron][para_index]             = sum_para_ary*local_grad_t   # multiply each element with local grad
#                     list_parameter_matrix[layer][perceptron][para_index]  -= grad_para_t[layer][perceptron][para_index]*learning_rate
                    
#                     local_grad_x                                           = y_out*(1-y_out)*old_para_matrix[layer][perceptron][para_index]
#                     grad_para_x[layer][perceptron][para_index]             = sum_para_ary*local_grad_x
